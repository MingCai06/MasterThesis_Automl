# %% [markdown]
# # Result of parallel BO with different number points in batch

# %% [markdown]
# According to former experiences, when q>=10 and calls to the Gaussian c.d.g become expensive. So in this experiment, i test the BO with 1-10 points under different iterations in one dataset.  Evaluation Criterions are **CPU Time** and **AUC score**. We should make a trade-off between those two Criterions.

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(20,8))
ax = fig.add_subplot(111)
width = 0.2
x_1 = score
x_2 = score_2
x_3 = score_3
x_4 = score_4
y = range(1,11)
y = np.arange(len(y)) 
ax.bar(y,x_3,width,alpha = 0.3,label="iterations20",color="#a3c9c7")#,color='grey', edgecolor='black'
ax.bar(y+width,x_1,width,alpha = 0.3,label="iterations40",color="#ff5f2e")
ax.bar(y+2*width,x_2,width,alpha = 0.3,label="iterations50",color="#fcbe32")
ax.bar(y+3*width,x_4,width,alpha = 0.3,label="iterations100",color="#004e66")
ax.set_xticks(y +width/2)
ax.set_ylim((0.688, 0.698))
ax.set_ylabel('AUC',fontsize='15')
ax.set_xticks([])
ax.legend()

ax2 = ax.twinx()
ax2.plot(t_20['npoints'],t_20['cpu_time'], label="iterations20",marker='*',ms=10,lw=3,color="#a3c9c7")
ax2.plot(t_40['npoints'],t_40['cpu_time'],label="iterations40",marker ="*",ms=10,lw=3,color="#ff5f2e")
ax2.plot(t_50['npoints'],t_50['cpu_time'],label="iterations50",marker ="*",ms=10,lw=3,color="#fcbe32")
ax2.plot(t_100['npoints'],t_100['cpu_time'],label="iterations100",marker ="*",ms=10,lw=3,color="#004e66")
ax2.set_ylabel('CPU time/s',fontsize='15')
ax2.set_xlabel('n-points')
ax2.grid()
ax2.legend()
fig.show()
fig.savefig(DIRS['output']+'auc_compare_npoints_time.png', dpi=fig.dpi)

# %% [markdown]
# These charts show the differences CPU time and AUC score between BO with four number of iterations.In the chart the different color represent differen iterations. When we look at the CPU time, the general trend appears to be decreased, except for the iteration 100 when the points = 7 is slight increase. On the other hand, bath with 6 points overwhelmingly greater than the corresponding figure of others.

# %% [markdown]
# # prepare & load data

# %%
import numpy as np
import base64
import os
from os.path import join
import sys

def mprint(msg):
    from datetime import datetime
    """info"""
    cur_time = datetime.now().strftime('%m-%d %H:%M:%S')
    print(f"INFO  [{cur_time}] {msg}")

def Config_DIRS():

    if len(sys.argv) == 1:
        # default local
        ROOT_DIR = os.getcwd()
        DIRS = {
            'input': join(ROOT_DIR, 'data'),
            'output': join(ROOT_DIR, 'predictions'),
            'program': join(ROOT_DIR, 'ingestion_program'),
            'submission': join(ROOT_DIR, 'automl')
        }
    elif len(sys.argv) == 3:
        # default local
        ROOT_DIR = os.getcwd()
        DIRS = {
            'input': join(ROOT_DIR, 'data'),
            'output': join(ROOT_DIR, 'predictions'),
            'program': join(ROOT_DIR, 'ingestion_program'),
            'submission': join(ROOT_DIR, 'automl')
        }

    elif len(sys.argv) == 5:
        # run in codalab
        DIRS = {
            'input': sys.argv[1],
            'output': sys.argv[2],
            'program': sys.argv[3],
            'submission': sys.argv[4]
        }
    elif len(sys.argv) == 6 and sys.argv[1] == 'local':
        # full call in local
        DIRS = {
            'input': sys.argv[2],
            'output': sys.argv[3],
            'program': sys.argv[4],
            'submission': sys.argv[5]
        }
    else:
        raise ValueError("Wrong number of arguments")
    sys.path.append(DIRS['submission'])
    print(DIRS)
    return(DIRS)

DIRS = Config_DIRS()

import reader

info = {
	"table_sep" : ',',
	"target_name" : 'defects',
	"miss_values":'?'
}


datanames = [f for f in os.listdir(DIRS['input']) if not f.startswith('.')]
reader = reader.Reader(sep = info['table_sep'],
						miss_values=info['miss_values']
						)

for dataname in datanames:
        mprint(f'Read data: {dataname}')
        datapath = join(DIRS['input'], dataname)

data = reader.read_split([datapath], target_name=info['target_name'])
print(data.keys())
# Out:
# {'input': '/Users/caicai/Desktop/Masterarbeit/AutoML/Automl_Framework/data', 'output': '/Users/caicai/Desktop/Masterarbeit/AutoML/Automl_Framework/predictions', 'program': '/Users/caicai/Desktop/Masterarbeit/AutoML/Automl_Framework/ingestion_program', 'submission': '/Users/caicai/Desktop/Masterarbeit/AutoML/Automl_Framework/automl'}
# INFO  [08-04 09:47:31] Read data: jm1.csv
#
# Start [read_split]:
# ----Start [pre_clean]:
#
# reading csv : jm1.csv ...
# cleaning data ...
# ----End   [pre_clean]. Time elapsed: 5.35 sec.
#
# > Number of common features : 21
#
# gathering and crunching for train and test datasets ...
# reindexing for train and test datasets ...
# dropping training duplicates ...
# dropping constant variables on training set ...
#
# > % missing values on train set:
# uniq_Opnd      0.0
# uniq_Op        0.0
# total_Opnd     0.0
# total_Op       0.0
# branchCount    0.0
# dtype: float64
#
# dropping columns with high missing rate >0.8...
# > No need to dropping!
#
# > Number of categorical features: 0
# > Number of numerical features: 21
# > Number of training samples : 6144
# > Number of test samples : 3593
#
# > Task : classification
# Train Traget
# 0.0    4788
# 1.0    1356
# Name: defects, dtype: int64
#
# Test Traget
# 0.0    2887
# 1.0     706
# Name: defects, dtype: int64
#
# encoding target ...
# training set encoding finished
# test set encoding finished
#
# Impute the Missing Values...
#
# End   [read_split]. Time elapsed: 5.54 sec.
# dict_keys(['train', 'test', 'target', 'y_test'])
# /Users/caicai/Desktop/Masterarbeit/AutoML/Automl_Framework/automl/reader.py:314: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_train[path] = train[~is_null].drop(target_name, axis=1)
# /anaconda3/lib/python3.7/site-packages/sklearn/utils/deprecation.py:58: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/utils/deprecation.py:58: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)

# %% [markdown]
# # optimisation

# %%
# Importing core libraries
import time
import pprint
import joblib
import pandas as pd

# Suppressing warnings because of skopt verbosity
import warnings
warnings.filterwarnings("ignore")

# Model selection
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score, KFold
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline

# Metrics
from sklearn.metrics import roc_auc_score
from sklearn.metrics import make_scorer

# Skopt functions
from skopt import BayesSearchCV
from skopt.space import Real, Categorical, Integer
from skopt.utils import use_named_args  # decorator to convert a list of parameters to named arguments
from skopt.callbacks import DeadlineStopper  # Stop the optimization before running out of a fixed budget of time.
from skopt.callbacks import VerboseCallback  # Callback to control the verbosity
from skopt.callbacks import DeltaXStopper  # Stop the optimization If the last two positions at which the objective has been evaluated are less than delta

# import local function
from util import log, timeit, mprint, dump_result, load_result
from encoder import Categorical_encoder
from scaling import Scaler
from model import Classifier
from feature_selection import feature_selector


class Optimiser():

    """Optimises hyper-parameters
    - Estimator (classifier )
    Parameters
    ----------
    scoring : str, callable or None. default: None
        A string or a scorer callable object.
        If None, "auc" is used for classification
        Available scorings for classification : {"accuracy","roc_auc", "f1",
        "log_loss", "precision", "recall"}
    n_folds : int, default = 3
        The number of folds for cross validation (stratified for classification)
    random_state : int, default = 42
        Pseudo-random number generator state used for shuffling
    save_result : bool, default = False
        weather models be saved
    verbose : bool, default = True
        Verbose mode
    Return
    ----------
    final_result : dict, result for all surrogated models
        - final_result['GP'] 
        - final_result['RF'] 
    ----------
    Example
    ----------
    from skopt.space import Real, Categorical, Integer
    from optimisation import Optimiser

    optimiser = Optimiser()

    df_train = data['train'] #df_test = data['test']
    y = data['target'] #y_test = data['y_test']
    search_space_LGB = Classifier(strategy = "LightGBM").get_search_spaces()
    search_space_RF  = Classifier(strategy = "RandomForest").get_search_spaces()

    best_param,results = optimiser.optimise_step(space = [(search_space_LGB_fs,5),(search_space_RF,5)],
                                df_train=X_train,
                                df_target=y_train,
                                max_evals = 5,
                                set_callbacks=True)
    """

    def __init__(self, scoring=None,
                 n_folds=5,
                 random_state=42,
                 verbose=True,
                 to_path="save",
                 perform_scaling=True,
                 parallel_strategy=True):

        self.scoring = scoring
        self.n_folds = n_folds
        self.random_state = random_state
        self.verbose = verbose
        self.to_path = to_path
        self.perform_scaling = perform_scaling
        self.parallel_strategy = parallel_strategy

        if self.to_path is True:
            warnings.warn("Optimiser will save all your fitted models result ")

        self.cv = StratifiedKFold(n_splits=self.n_folds, shuffle=True, random_state=self.random_state)

        # Default scoring for classification
        if (self.scoring is None):
            self.scoring = make_scorer(roc_auc_score, greater_is_better=True, needs_threshold=True)

        elif (self.scoring == "log_loss"):
            self.scoring = 'log_loss'

        else:
            if (type(self.scoring) == str):
                if (self.scoring in ["accuracy", "roc_auc", "f1",
                                     "log_loss", "precision", "recall"]):
                    pass
                else:
                    warnings.warn("Invalid scoring metric. "
                                  "auc is used instead.")
                    self.scoring is None
            else:
                pass

    def get_params(self, deep=True):

        return {'scoring': self.scoring,
                'n_folds': self.n_folds,
                'random_state': self.random_state,
                'verbose': self.verbose,
                'save_result': self.save_result,
                'perform_scaling': self.perform_scaling,
                'parallel_strategy': self.parallel_strategy}

    def set_params(self, **params):

        self.__fitOK = False

        for k, v in params.items():
            if k not in self.get_params():
                warnings.warn("Invalid parameter a for optimiser Optimiser. "
                              "Parameter IGNORED. Check the list of available "
                              "parameters with `optimiser.get_params().keys()`")
            else:
                setattr(self, k, v)

    @timeit
    def optimise_step(self, space, df_train, df_target, max_evals=20, npoints=4, set_callbacks=True):
        """Evaluates the data.
        Build the pipeline. If no parameters are set, default configuration for
        each step is used
        Parameters
        ----------
        space : dict, default = None.
        df_train : pandas dataframe of shape = (n_train, n_features)
            The train dataset with numerical features.
        y_train : pandas series of shape = (n_train,)
            The numerical encoded target for classification tasks.
        max_evals : int, default = 20, max evaluation times
        set_callbacks (opt): bool,default: True
             If callable then callback(res) is called after each call to func. If list of callables, then each callable in the list is called.
        ----------
        Returns
        ---------
        result : dict
            - result['best_score'] : Best Score after Tuning
            - result['best_score_std'] : Standar Divation of best score
            - result['best_parmas'] : Best parameters
            - result['params'] : all paramsters (# = checked candicated)
            - result['time_cost(s)'] : total time of finding out the best parameters
            - result['all_cv_results'] : all cv results
            - result['mean_score_time'] : time for each cv result
        """
        # checke parallel strategy

        ce = Categorical_encoder()
        X = ce.fit_transform(df_train, df_target)

        if self.perform_scaling is True:
            scal = Scaler()
            X = scal.fit_transform(X, df_target)

        mid_result = {}
        tuning_result = {}

#        lgb = Classifier(strategy="LightGBM").get_estimator()
#        rf = Classifier(strategy="RandomForest").get_estimator()

        # Creating a correct space for skopt
        if (space is None):
            warnings.warn(
                "Space is empty. Please define a search space. "
                "Otherwise, call the method 'evaluate' for custom settings")
            return dict()

        else:

            if (len(space) == 0):
                warnings.warn(
                    "Space is empty. Please define a search space. "
                    "Otherwise, call the method 'evaluate' for custom settings")
                return dict()

            else:
                search_spaces = space

                # Initialize a pipeline
                fs = None
                for i in range(len(search_spaces)):
                    for p in search_spaces[i][0].keys():
                        if (p.startswith("fs__")):
                            fs = feature_selector()
                        else:
                            pass

                # Do we need to cache transformers?
                cache = False

                if (fs is not None):
                    if ("fs__strategy" in search_spaces):
                        if(search_spaces["fs__strategy"] != "variance"):
                            cache = True
                        else:
                            pass
                else:
                    pass
                mprint(f'Start turning Hyperparameters .... ')
                print("")
                print(">>> Categorical Features have encoded with :" + str({'strategy': ce.strategy}))
                print("")
                if self.perform_scaling is True:
                    print(">>> Numerical Features have encoded with :" + scal.__class__.__name__)
                    print("")

                for baseEstimator in ['GP', 'RF']:
                    # Pipeline creation

                    lgb = Classifier(strategy="LightGBM").get_estimator()
                  #  rf = Classifier(strategy="RandomForest").get_estimator()
                  #  svc = Classifier(strategy="SVC").get_estimator()

                    if (fs is not None):
                        if cache:
                            pipe = Pipeline([('fs', fs), ('model', lgb)], memory=self.to_path)
                        else:
                            pipe = Pipeline([('fs', fs), ('model', lgb)])
                    else:
                        if cache:
                            pipe = Pipeline([('model', lgb)], memory=self.to_path)
                        else:
                            pipe = Pipeline([('model', lgb)])

                    if (self.parallel_strategy is True):
                        opt = BayesSearchCV(pipe,
                                            search_spaces=search_spaces,
                                            scoring=self.scoring,
                                            cv=self.cv,
                                            n_points=npoints,
                                            n_jobs=-1,
                                            return_train_score=False,
                                            optimizer_kwargs={'base_estimator': baseEstimator,
                                                              "acq_func": "EI"},
                                            random_state=self.random_state,
                                            verbose=self.verbose)
                    else:
                        opt = BayesSearchCV(pipe,
                                            search_spaces=search_spaces,
                                            scoring=self.scoring,
                                            cv=self.cv,
                                            n_points=npoints,
                                            n_jobs=1,
                                            #         n_iter=max_evals,
                                            return_train_score=False,
                                            optimizer_kwargs={'base_estimator': baseEstimator,
                                                              "acq_func": "EIps"},
                                            random_state=self.random_state,
                                            verbose=self.verbose)

                    if set_callbacks is True:

                        mid_result = self.report_perf(opt, X, df_target, ' with Surrogate Model:' + baseEstimator,
                                                      callbacks=[DeltaXStopper(0.0001), DeadlineStopper(60 * 5)
                                                                 ])
                    else:
                        mid_result = self.report_perf(opt, X, df_target, ' with Surrogate Model: ' + baseEstimator,
                                                      )
                    tuning_result[baseEstimator] = mid_result

        bests = pd.DataFrame()
        for key in tuning_result.keys():
            if tuning_result[key]['best_score'] == max(d['best_score'] for d in tuning_result.values()):
                bests = bests.append({'best_score': tuning_result[key]['best_score'],
                                      'best_SM': key,
                                      'time': tuning_result[key]['CPU_Time']}, ignore_index=True)
                bests.sort_values(by=['time'])
                best_base_estimator = bests['best_SM'][0]
                best_param = tuning_result[best_base_estimator]['best_parmas']

        print("")
        print('######## Congratulations! Here is the Best Parameters: #######')
        print('Best Score is:', tuning_result[best_base_estimator]['best_score'])
        print('with Surrogate Model ' + best_base_estimator)
        pprint.pprint(best_param)
        return best_param, tuning_result

    # Define Call back function
    # def on_step(self, optim_result):
    #     score = opt.best_score_
    #     score_std = opt.cv_results_['std_test_score'][opt.best_index_]
    #     if score >= 0.99:
    #         print('Best Score >0.99,Interrupting!')
    #         return True

    # Reporting util for different optimizers
    def report_perf(self, optimizer, X, y, title, callbacks=None):
        """
        optimizer = a sklearn or a skopt optimizer
        X = the training set 
        y = our target
        title = a string label for the experiment
        """
        start = time.time()
        start_cpu = time.process_time()
        if callbacks:
            mprint(f'start tuning {title}...')

            optimizer.fit(X, y, callback=callbacks)
        else:
            mprint(f'start tuning {title}...')

            optimizer.fit(X, y)

        time_cost_CPU = time.process_time() - start_cpu
        time_cost = time.time() - start
        result = {}
        result['best_score'] = optimizer.best_score_
        result['best_score_std'] = optimizer.cv_results_['std_test_score'][optimizer.best_index_]
        result['best_parmas'] = optimizer.best_params_
        result['params'] = optimizer.cv_results_['params']
        result['CPU_Time'] = round(time_cost_CPU, 0)
        result['Time_cost'] = round(time_cost, 0)
        result['all_cv_results'] = optimizer.cv_results_['mean_test_score'][:]
        result['CV'] = optimizer.cv_results_
        print("")
#        print('>' + title + ':')
        time_cost_CPU = round(result['CPU_Time'], 0)
        time_cost = round(result['Time_cost'], 0)
        cand = len(result['all_cv_results'])
        best_cv = round(result['best_score'], 8)
        best_cv_sd = round(result['best_score_std'], 4)
        print(f'took CPU Time: {time_cost_CPU}s,clock time: {time_cost}, candidates checked:{cand} ,best CV score: {best_cv} \u00B1 {best_cv_sd}')
        print("")

        return result

# %% [markdown]
# ## Parallel

# %%
from sklearn.model_selection import train_test_split
from skopt.space import Real, Categorical, Integer
#from optimisation_fs import Optimiser
from model import Classifier
import pandas as pd
from util import dump_result,load_result

df_train = data['train'] #df_test = data['test']
#df_train = pd.DataFrame(df_train)
y = data['target'] #y_test = data['y_test']

#X_train, X_val,y_train,y_val= train_test_split(df_train,y, test_size=0.6,random_state=42)
np_best_param = {}
np_results = {}
for n in range(1,11):
    nname = "npoints_"+str(n)
    print("")
    print(">>>>>> npoints:",n )
    optimiser = Optimiser(verbose=0,n_folds=5,parallel_strategy=True)
    search_space_LGB = Classifier(strategy = "LightGBM").get_search_spaces(need_feature_selection=False)
    search_space_SVC = Classifier(strategy = "SVC").get_search_spaces(need_feature_selection=False)

    best_param,results = optimiser.optimise_step( space = [(search_space_LGB,50),(search_space_SVC,50)],
                                                  df_train=df_train,
                                                  df_target=y,
                                                  set_callbacks=True,
                                                  npoints=n)
    
    np_best_param[nname] = best_param
    np_results[nname] = results
    
dump_result(np_results,"parallel_np_5f_50_eips",save_with_time=True)
dump_result(np_best_param,"best_param_5f_50_eips",save_with_time=True)
# Out:
# >>>>>> npoints: 1
#
# Start [optimise_step]:
# INFO  [07-20 19:14:49] Start turning Hyperparameters ....
#
# >>> Categorical Features have encoded with :{'strategy': 'label_encoding'}
#
# >>> Numerical Features have encoded with :Scaler
#
# INFO  [07-20 19:14:49] start tuning  with Surrogate Model:GP...
#
# took CPU Time: 496.0s,clock time: 228.0, candidates checked:99 ,best CV score: 0.69285553 ± 0.0117
#
# INFO  [07-20 19:18:37] start tuning  with Surrogate Model:RF...
#
# took CPU Time: 158.0s,clock time: 158.0, candidates checked:100 ,best CV score: 0.69517059 ± 0.0128
#
#
# ######## Congratulations! Here is the Best Parameters: #######
# Best Score is: 0.6951705862224818
# with Surrogate Model RF
# {'model': LGBMClassifier(boosting_type='dart', class_weight=None, colsample_bytree=1.0,
#         feature_fraction=0.6269410062950892, importance_type='split',
#         is_unbalance=True, learning_rate=0.7549437155154509, max_bin=8701,
#         max_depth=-1, min_child_samples=20, min_child_weight=0.001,
#         min_split_gain=0.0, n_estimators=69, n_jobs=-1, nthread=-1,
#         num_leaves=31, objective='binary', random_state=None,
#         reg_alpha=1.4726135556206274e-07, reg_lambda=404.6407085815774,
#         seed=0, silent=True, subsample=1.0, subsample_for_bin=200000,
#         subsample_freq=0),
#  'model__boosting_type': 'dart',
#  'model__feature_fraction': 0.6269410062950892,
#  'model__is_unbalance': True,
#  'model__learning_rate': 0.7549437155154509,
#  'model__max_bin': 8701,
#  'model__n_estimators': 69,
#  'model__reg_alpha': 1.4726135556206274e-07,
#  'model__reg_lambda': 404.6407085815774}
# End   [optimise_step]. Time elapsed: 386.31 sec.
#
# >>>>>> npoints: 2
#
# Start [optimise_step]:
# INFO  [07-20 19:21:16] Start turning Hyperparameters ....
#
# >>> Categorical Features have encoded with :{'strategy': 'label_encoding'}
#
# >>> Numerical Features have encoded with :Scaler
#
# INFO  [07-20 19:21:16] start tuning  with Surrogate Model:GP...
#
# took CPU Time: 361.0s,clock time: 237.0, candidates checked:94 ,best CV score: 0.69414795 ± 0.0132
#
# INFO  [07-20 19:25:13] start tuning  with Surrogate Model:RF...
#
# took CPU Time: 130.0s,clock time: 173.0, candidates checked:100 ,best CV score: 0.69107334 ± 0.0115
#
#
# ######## Congratulations! Here is the Best Parameters: #######
# Best Score is: 0.6941479487935117
# with Surrogate Model GP
# {'model': LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         feature_fraction=1.0, importance_type='split', is_unbalance=True,
#         learning_rate=0.01, max_bin=9282, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=401, n_jobs=-1, nthread=-1, num_leaves=31,
#         objective='binary', random_state=None,
#         reg_alpha=2.6614042651693355e-07, reg_lambda=53.654801586986494,
#         seed=0, silent=True, subsample=1.0, subsample_for_bin=200000,
#         subsample_freq=0),
#  'model__boosting_type': 'gbdt',
#  'model__feature_fraction': 1.0,
#  'model__is_unbalance': True,
#  'model__learning_rate': 0.01,
#  'model__max_bin': 9282,
#  'model__n_estimators': 401,
#  'model__reg_alpha': 2.6614042651693355e-07,
#  'model__reg_lambda': 53.654801586986494}
# End   [optimise_step]. Time elapsed: 410.41 sec.
#
# >>>>>> npoints: 3
#
# Start [optimise_step]:
# INFO  [07-20 19:28:06] Start turning Hyperparameters ....
#
# >>> Categorical Features have encoded with :{'strategy': 'label_encoding'}
#
# >>> Numerical Features have encoded with :Scaler
#
# INFO  [07-20 19:28:06] start tuning  with Surrogate Model:GP...
#
# took CPU Time: 299.0s,clock time: 212.0, candidates checked:98 ,best CV score: 0.69038989 ± 0.0155
#
# INFO  [07-20 19:31:38] start tuning  with Surrogate Model:RF...
#
# took CPU Time: 108.0s,clock time: 136.0, candidates checked:100 ,best CV score: 0.69238364 ± 0.0137
#
#
# ######## Congratulations! Here is the Best Parameters: #######
# Best Score is: 0.692383644490261
# with Surrogate Model RF
# {'model': LGBMClassifier(boosting_type='dart', class_weight=None, colsample_bytree=1.0,
#         feature_fraction=0.7323482856973, importance_type='split',
#         is_unbalance=True, learning_rate=0.12025137196124303, max_bin=1080,
#         max_depth=-1, min_child_samples=20, min_child_weight=0.001,
#         min_split_gain=0.0, n_estimators=449, n_jobs=-1, nthread=-1,
#         num_leaves=31, objective='binary', random_state=None,
#         reg_alpha=23.356308774867575, reg_lambda=1.6296774452630643e-09,
#         seed=0, silent=True, subsample=1.0, subsample_for_bin=200000,
#         subsample_freq=0),
#  'model__boosting_type': 'dart',
#  'model__feature_fraction': 0.7323482856973,
#  'model__is_unbalance': True,
#  'model__learning_rate': 0.12025137196124303,
#  'model__max_bin': 1080,
#  'model__n_estimators': 449,
#  'model__reg_alpha': 23.356308774867575,
#  'model__reg_lambda': 1.6296774452630643e-09}
# End   [optimise_step]. Time elapsed: 348.58 sec.
#
# >>>>>> npoints: 4
#
# Start [optimise_step]:
# INFO  [07-20 19:33:55] Start turning Hyperparameters ....
#
# >>> Categorical Features have encoded with :{'strategy': 'label_encoding'}
#
# >>> Numerical Features have encoded with :Scaler
#
# INFO  [07-20 19:33:55] start tuning  with Surrogate Model:GP...
#
# took CPU Time: 296.0s,clock time: 217.0, candidates checked:100 ,best CV score: 0.69262167 ± 0.0102
#
# INFO  [07-20 19:37:32] start tuning  with Surrogate Model:RF...
#
# took CPU Time: 66.0s,clock time: 89.0, candidates checked:100 ,best CV score: 0.69013916 ± 0.0138
#
#
# ######## Congratulations! Here is the Best Parameters: #######
# Best Score is: 0.6926216680791087
# with Surrogate Model GP
# {'model': LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         feature_fraction=0.35761093532565036, importance_type='split',
#         is_unbalance=False, learning_rate=0.2210415001055415, max_bin=100,
#         max_depth=-1, min_child_samples=20, min_child_weight=0.001,
#         min_split_gain=0.0, n_estimators=500, n_jobs=-1, nthread=-1,
#         num_leaves=31, objective='binary', random_state=None,
#         reg_alpha=0.05730553855974484, reg_lambda=1000.0, seed=0,
#         silent=True, subsample=1.0, subsample_for_bin=200000,
#         subsample_freq=0),
#  'model__boosting_type': 'gbdt',
#  'model__feature_fraction': 0.35761093532565036,
#  'model__is_unbalance': False,
#  'model__learning_rate': 0.2210415001055415,
#  'model__max_bin': 100,
#  'model__n_estimators': 500,
#  'model__reg_alpha': 0.05730553855974484,
#  'model__reg_lambda': 1000.0}
# End   [optimise_step]. Time elapsed: 306.61 sec.
#
# >>>>>> npoints: 5
#
# Start [optimise_step]:
# INFO  [07-20 19:39:02] Start turning Hyperparameters ....
#
# >>> Categorical Features have encoded with :{'strategy': 'label_encoding'}
#
# >>> Numerical Features have encoded with :Scaler
#
# INFO  [07-20 19:39:02] start tuning  with Surrogate Model:GP...
#
# took CPU Time: 258.0s,clock time: 198.0, candidates checked:100 ,best CV score: 0.69086734 ± 0.0075
#
# INFO  [07-20 19:42:19] start tuning  with Surrogate Model:RF...
#
# took CPU Time: 64.0s,clock time: 91.0, candidates checked:100 ,best CV score: 0.69268974 ± 0.0098
#
#
# ######## Congratulations! Here is the Best Parameters: #######
# Best Score is: 0.6926897373868456
# with Surrogate Model RF
# {'model': LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         feature_fraction=0.7515808725135097, importance_type='split',
#         is_unbalance=False, learning_rate=0.1274347139619803, max_bin=8077,
#         max_depth=-1, min_child_samples=20, min_child_weight=0.001,
#         min_split_gain=0.0, n_estimators=39, n_jobs=-1, nthread=-1,
#         num_leaves=31, objective='binary', random_state=None,
#         reg_alpha=0.006108301040179926, reg_lambda=44.80782801012955,
#         seed=0, silent=True, subsample=1.0, subsample_for_bin=200000,
#         subsample_freq=0),
#  'model__boosting_type': 'gbdt',
#  'model__feature_fraction': 0.7515808725135097,
#  'model__is_unbalance': False,
#  'model__learning_rate': 0.1274347139619803,
#  'model__max_bin': 8077,
#  'model__n_estimators': 39,
#  'model__reg_alpha': 0.006108301040179926,
#  'model__reg_lambda': 44.80782801012955}
# End   [optimise_step]. Time elapsed: 288.21 sec.
#
# >>>>>> npoints: 6
#
# Start [optimise_step]:
# INFO  [07-20 19:43:50] Start turning Hyperparameters ....
#
# >>> Categorical Features have encoded with :{'strategy': 'label_encoding'}
#
# >>> Numerical Features have encoded with :Scaler
#
# INFO  [07-20 19:43:50] start tuning  with Surrogate Model:GP...
# took CPU Time: 269.0s,clock time: 214.0, candidates checked:100 ,best CV score: 0.69630667 ± 0.0129
#
# INFO  [07-20 19:47:23] start tuning  with Surrogate Model:RF...
#
# took CPU Time: 73.0s,clock time: 97.0, candidates checked:100 ,best CV score: 0.6890559 ± 0.0074
#
#
# ######## Congratulations! Here is the Best Parameters: #######
# Best Score is: 0.6963066728484417
# with Surrogate Model GP
# {'model': LGBMClassifier(boosting_type='dart', class_weight=None, colsample_bytree=1.0,
#         feature_fraction=1.0, importance_type='split', is_unbalance=False,
#         learning_rate=1.0, max_bin=100, max_depth=-1, min_child_samples=20,
#         min_child_weight=0.001, min_split_gain=0.0, n_estimators=500,
#         n_jobs=-1, nthread=-1, num_leaves=31, objective='binary',
#         random_state=None, reg_alpha=1e-09, reg_lambda=1000.0, seed=0,
#         silent=True, subsample=1.0, subsample_for_bin=200000,
#         subsample_freq=0),
#  'model__boosting_type': 'dart',
#  'model__feature_fraction': 1.0,
#  'model__is_unbalance': False,
#  'model__learning_rate': 1.0,
#  'model__max_bin': 100,
#  'model__n_estimators': 500,
#  'model__reg_alpha': 1e-09,
#  'model__reg_lambda': 1000.0}
# End   [optimise_step]. Time elapsed: 310.60 sec.
#
# >>>>>> npoints: 7
#
# Start [optimise_step]:
# INFO  [07-20 19:49:00] Start turning Hyperparameters ....
#
# >>> Categorical Features have encoded with :{'strategy': 'label_encoding'}
#
# >>> Numerical Features have encoded with :Scaler
#
# INFO  [07-20 19:49:00] start tuning  with Surrogate Model:GP...
#
# took CPU Time: 261.0s,clock time: 180.0, candidates checked:99 ,best CV score: 0.69531304 ± 0.0098
#
# INFO  [07-20 19:52:00] start tuning  with Surrogate Model:RF...
#
# took CPU Time: 67.0s,clock time: 260.0, candidates checked:78 ,best CV score: 0.68814016 ± 0.0142
#
#
# ######## Congratulations! Here is the Best Parameters: #######
# Best Score is: 0.695313038231781
# with Surrogate Model GP
# {'model': LGBMClassifier(boosting_type='dart', class_weight=None, colsample_bytree=1.0,
#         feature_fraction=0.5638663724893178, importance_type='split',
#         is_unbalance=False, learning_rate=1.0, max_bin=100, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=500, n_jobs=-1, nthread=-1, num_leaves=31,
#         objective='binary', random_state=None, reg_alpha=1e-09,
#         reg_lambda=1000.0, seed=0, silent=True, subsample=1.0,
#         subsample_for_bin=200000, subsample_freq=0),
#  'model__boosting_type': 'dart',
#  'model__feature_fraction': 0.5638663724893178,
#  'model__is_unbalance': False,
#  'model__learning_rate': 1.0,
#  'model__max_bin': 100,
#  'model__n_estimators': 500,
#  'model__reg_alpha': 1e-09,
#  'model__reg_lambda': 1000.0}
# End   [optimise_step]. Time elapsed: 440.00 sec.
#
# >>>>>> npoints: 8
#
# Start [optimise_step]:
# INFO  [07-20 19:56:20] Start turning Hyperparameters ....
#
# >>> Categorical Features have encoded with :{'strategy': 'label_encoding'}
#
# >>> Numerical Features have encoded with :Scaler
#
# INFO  [07-20 19:56:20] start tuning  with Surrogate Model:GP...
#
# took CPU Time: 233.0s,clock time: 157.0, candidates checked:100 ,best CV score: 0.69415188 ± 0.0088
#
# INFO  [07-20 19:58:57] start tuning  with Surrogate Model:RF...
#
# took CPU Time: 95.0s,clock time: 138.0, candidates checked:100 ,best CV score: 0.69303468 ± 0.0144
#
#
# ######## Congratulations! Here is the Best Parameters: #######
# Best Score is: 0.6941518773612797
# with Surrogate Model GP
# {'model': LGBMClassifier(boosting_type='dart', class_weight=None, colsample_bytree=1.0,
#         feature_fraction=0.6536984466079172, importance_type='split',
#         is_unbalance=False, learning_rate=0.8837202053873043,
#         max_bin=10000, max_depth=-1, min_child_samples=20,
#         min_child_weight=0.001, min_split_gain=0.0, n_estimators=298,
#         n_jobs=-1, nthread=-1, num_leaves=31, objective='binary',
#         random_state=None, reg_alpha=3.1148696464382652e-09,
#         reg_lambda=1000.0, seed=0, silent=True, subsample=1.0,
#         subsample_for_bin=200000, subsample_freq=0),
#  'model__boosting_type': 'dart',
#  'model__feature_fraction': 0.6536984466079172,
#  'model__is_unbalance': False,
#  'model__learning_rate': 0.8837202053873043,
#  'model__max_bin': 10000,
#  'model__n_estimators': 298,
#  'model__reg_alpha': 3.1148696464382652e-09,
#  'model__reg_lambda': 1000.0}
# End   [optimise_step]. Time elapsed: 295.23 sec.
#
# >>>>>> npoints: 9
#
# Start [optimise_step]:
# INFO  [07-20 20:01:16] Start turning Hyperparameters ....
#
# >>> Categorical Features have encoded with :{'strategy': 'label_encoding'}
#
# >>> Numerical Features have encoded with :Scaler
#
# INFO  [07-20 20:01:16] start tuning  with Surrogate Model:GP...
#
# took CPU Time: 235.0s,clock time: 188.0, candidates checked:100 ,best CV score: 0.69338953 ± 0.0117
#
# INFO  [07-20 20:04:24] start tuning  with Surrogate Model:RF...
#
# took CPU Time: 56.0s,clock time: 82.0, candidates checked:100 ,best CV score: 0.67824858 ± 0.0106
#
#
# ######## Congratulations! Here is the Best Parameters: #######
# Best Score is: 0.6933895330080385
# with Surrogate Model GP
# {'model': LGBMClassifier(boosting_type='dart', class_weight=None, colsample_bytree=1.0,
#         feature_fraction=0.3934491325295981, importance_type='split',
#         is_unbalance=True, learning_rate=0.6285803549901531, max_bin=7850,
#         max_depth=-1, min_child_samples=20, min_child_weight=0.001,
#         min_split_gain=0.0, n_estimators=335, n_jobs=-1, nthread=-1,
#         num_leaves=31, objective='binary', random_state=None,
#         reg_alpha=8.21696992146695e-09, reg_lambda=659.7242559847532,
#         seed=0, silent=True, subsample=1.0, subsample_for_bin=200000,
#         subsample_freq=0),
#  'model__boosting_type': 'dart',
#  'model__feature_fraction': 0.3934491325295981,
#  'model__is_unbalance': True,
#  'model__learning_rate': 0.6285803549901531,
#  'model__max_bin': 7850,
#  'model__n_estimators': 335,
#  'model__reg_alpha': 8.21696992146695e-09,
#  'model__reg_lambda': 659.7242559847532}
# End   [optimise_step]. Time elapsed: 269.46 sec.
#
# >>>>>> npoints: 10
#
# Start [optimise_step]:
# INFO  [07-20 20:05:45] Start turning Hyperparameters ....
#
# >>> Categorical Features have encoded with :{'strategy': 'label_encoding'}
#
# >>> Numerical Features have encoded with :Scaler
#
# INFO  [07-20 20:05:45] start tuning  with Surrogate Model:GP...
#
# took CPU Time: 225.0s,clock time: 185.0, candidates checked:100 ,best CV score: 0.6955799 ± 0.0114
#
# INFO  [07-20 20:08:50] start tuning  with Surrogate Model:RF...
#
# took CPU Time: 56.0s,clock time: 87.0, candidates checked:100 ,best CV score: 0.67824858 ± 0.0106
#
#
# ######## Congratulations! Here is the Best Parameters: #######
# Best Score is: 0.6955799046049255
# with Surrogate Model GP
# {'model': LGBMClassifier(boosting_type='dart', class_weight=None, colsample_bytree=1.0,
#         feature_fraction=0.9607740051068241, importance_type='split',
#         is_unbalance=False, learning_rate=0.8788203853954335, max_bin=3171,
#         max_depth=-1, min_child_samples=20, min_child_weight=0.001,
#         min_split_gain=0.0, n_estimators=500, n_jobs=-1, nthread=-1,
#         num_leaves=31, objective='binary', random_state=None,
#         reg_alpha=1e-09, reg_lambda=1000.0, seed=0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0),
#  'model__boosting_type': 'dart',
#  'model__feature_fraction': 0.9607740051068241,
#  'model__is_unbalance': False,
#  'model__learning_rate': 0.8788203853954335,
#  'model__max_bin': 3171,
#  'model__n_estimators': 500,
#  'model__reg_alpha': 1e-09,
#  'model__reg_lambda': 1000.0}
# End   [optimise_step]. Time elapsed: 272.13 sec.
# Dump successful! File Name: jm1_parallel_np_5f_50_eips_20190720201017.json
# Dump successful! File Name: jm1_best_param_5f_50_eips_20190720201045.json

# %%
score = []
for k in np_results.keys():
    bests = pd.DataFrame()
    for key in np_results[k].keys():
        if np_results[k][key]['best_score'] == max(d['best_score'] for d in np_results[k].values()):
            bests = bests.append({'best_score': np_results[k][key]['best_score'],
                                  'best_SM': key,
                                  'time': np_results[k][key]['CPU_Time']}, ignore_index=True)
            bests.sort_values(by=['time'])
            best_base_estimator = bests['best_SM'][0]
    #print(np_results[k][best_base_estimator]['best_score'])
    score.append(np_results[k][best_base_estimator]['best_score'])

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(20,8))
ax = fig.add_subplot(111)
x_points = score
y = range(1,11)
p = ax.plot(y,x_points, 'b',marker =".",markersize = 15)
ax.set_xlabel('n-points')
plt.grid()
fig.show()

# %%
from sklearn.model_selection import train_test_split
from skopt.space import Real, Categorical, Integer
#from optimisation_fs import Optimiser
from model import Classifier
import pandas as pd
from util import dump_result,load_result

df_train = data['train'] #df_test = data['test']
#df_train = pd.DataFrame(df_train)
y = data['target'] #y_test = data['y_test']

#X_train, X_val,y_train,y_val= train_test_split(df_train,y, test_size=0.6,random_state=42)
np_best_param = {}
np_results = {}
for n in range(1,11):
    nname = "npoints_"+str(n)
    print("")
    print(">>>>>> npoints:",n )
    optimiser = Optimiser(verbose=0,n_folds=5,parallel_strategy=True)
    search_space_LGB = Classifier(strategy = "LightGBM").get_search_spaces(need_feature_selection=False)
    search_space_SVC = Classifier(strategy = "SVC").get_search_spaces(need_feature_selection=False)

    best_param,results = optimiser.optimise_step( space = [(search_space_LGB,20),(search_space_SVC,20)],
                                                  df_train=df_train,
                                                  df_target=y,
                                                  set_callbacks=True,
                                                  npoints=n)
    
    np_best_param[nname] = best_param
    np_results[nname] = results
    
dump_result(np_results,"parallel_np_5f_20_eips",save_with_time=True)
dump_result(np_best_param,"best_param_5f_20_eips",save_with_time=True)
# Out:
# >>>>>> npoints: 1
#
# Start [optimise_step]:
# INFO  [07-20 20:10:46] Start turning Hyperparameters ....
#
# >>> Categorical Features have encoded with :{'strategy': 'label_encoding'}
#
# >>> Numerical Features have encoded with :Scaler
#
# INFO  [07-20 20:10:46] start tuning  with Surrogate Model:GP...
#
# took CPU Time: 96.0s,clock time: 63.0, candidates checked:40 ,best CV score: 0.69004015 ± 0.0128
#
# INFO  [07-20 20:11:49] start tuning  with Surrogate Model:RF...
#
# took CPU Time: 64.0s,clock time: 87.0, candidates checked:40 ,best CV score: 0.69402932 ± 0.0144
#
#
# ######## Congratulations! Here is the Best Parameters: #######
# Best Score is: 0.6940293206601295
# with Surrogate Model RF
# {'model': LGBMClassifier(boosting_type='dart', class_weight=None, colsample_bytree=1.0,
#         feature_fraction=0.8729354091785828, importance_type='split',
#         is_unbalance=True, learning_rate=0.38725411714951785, max_bin=8978,
#         max_depth=-1, min_child_samples=20, min_child_weight=0.001,
#         min_split_gain=0.0, n_estimators=100, n_jobs=-1, nthread=-1,
#         num_leaves=31, objective='binary', random_state=None,
#         reg_alpha=1.3176450207192752e-08, reg_lambda=301.94140777972746,
#         seed=0, silent=True, subsample=1.0, subsample_for_bin=200000,
#         subsample_freq=0),
#  'model__boosting_type': 'dart',
#  'model__feature_fraction': 0.8729354091785828,
#  'model__is_unbalance': True,
#  'model__learning_rate': 0.38725411714951785,
#  'model__max_bin': 8978,
#  'model__n_estimators': 100,
#  'model__reg_alpha': 1.3176450207192752e-08,
#  'model__reg_lambda': 301.94140777972746}
# End   [optimise_step]. Time elapsed: 150.25 sec.
#
# >>>>>> npoints: 2
#
# Start [optimise_step]:
# INFO  [07-20 20:13:16] Start turning Hyperparameters ....
#
# >>> Categorical Features have encoded with :{'strategy': 'label_encoding'}
#
# >>> Numerical Features have encoded with :Scaler
#
# INFO  [07-20 20:13:16] start tuning  with Surrogate Model:GP...
#
# took CPU Time: 86.0s,clock time: 62.0, candidates checked:40 ,best CV score: 0.69414795 ± 0.0132
#
# INFO  [07-20 20:14:18] start tuning  with Surrogate Model:RF...
#
# took CPU Time: 72.0s,clock time: 93.0, candidates checked:40 ,best CV score: 0.68002849 ± 0.0165
#
#
# ######## Congratulations! Here is the Best Parameters: #######
# Best Score is: 0.6941479487935117
# with Surrogate Model GP
# {'model': LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         feature_fraction=1.0, importance_type='split', is_unbalance=True,
#         learning_rate=0.01, max_bin=9282, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=401, n_jobs=-1, nthread=-1, num_leaves=31,
#         objective='binary', random_state=None,
#         reg_alpha=2.6614042651693355e-07, reg_lambda=53.654801586986494,
#         seed=0, silent=True, subsample=1.0, subsample_for_bin=200000,
#         subsample_freq=0),
#  'model__boosting_type': 'gbdt',
#  'model__feature_fraction': 1.0,
#  'model__is_unbalance': True,
#  'model__learning_rate': 0.01,
#  'model__max_bin': 9282,
#  'model__n_estimators': 401,
#  'model__reg_alpha': 2.6614042651693355e-07,
#  'model__reg_lambda': 53.654801586986494}
# End   [optimise_step]. Time elapsed: 154.64 sec.
#
# >>>>>> npoints: 3
#
# Start [optimise_step]:
# INFO  [07-20 20:15:51] Start turning Hyperparameters ....
#
# >>> Categorical Features have encoded with :{'strategy': 'label_encoding'}
#
# >>> Numerical Features have encoded with :Scaler
#
# INFO  [07-20 20:15:51] start tuning  with Surrogate Model:GP...
#
# took CPU Time: 67.0s,clock time: 56.0, candidates checked:40 ,best CV score: 0.69038989 ± 0.0155
#
# INFO  [07-20 20:16:46] start tuning  with Surrogate Model:RF...
#
# took CPU Time: 32.0s,clock time: 48.0, candidates checked:40 ,best CV score: 0.66818691 ± 0.0091
#
#
# ######## Congratulations! Here is the Best Parameters: #######
# Best Score is: 0.6903898902285949
# with Surrogate Model GP
# {'model': LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         feature_fraction=1.0, importance_type='split', is_unbalance=False,
#         learning_rate=0.0523189815562026, max_bin=6668, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=500, n_jobs=-1, nthread=-1, num_leaves=31,
#         objective='binary', random_state=None, reg_alpha=7.793139534387665,
#         reg_lambda=0.0002680799544207528, seed=0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0),
#  'model__boosting_type': 'gbdt',
#  'model__feature_fraction': 1.0,
#  'model__is_unbalance': False,
#  'model__learning_rate': 0.0523189815562026,
#  'model__max_bin': 6668,
#  'model__n_estimators': 500,
#  'model__reg_alpha': 7.793139534387665,
#  'model__reg_lambda': 0.0002680799544207528}
# End   [optimise_step]. Time elapsed: 103.68 sec.
#
# >>>>>> npoints: 4
#
# Start [optimise_step]:
# INFO  [07-20 20:17:34] Start turning Hyperparameters ....
#
# >>> Categorical Features have encoded with :{'strategy': 'label_encoding'}
#
# >>> Numerical Features have encoded with :Scaler
#
# INFO  [07-20 20:17:35] start tuning  with Surrogate Model:GP...
#
# took CPU Time: 64.0s,clock time: 51.0, candidates checked:40 ,best CV score: 0.69005082 ± 0.0087
#
# INFO  [07-20 20:18:26] start tuning  with Surrogate Model:RF...
#
# took CPU Time: 26.0s,clock time: 39.0, candidates checked:40 ,best CV score: 0.68782378 ± 0.0074
#
#
# ######## Congratulations! Here is the Best Parameters: #######
# Best Score is: 0.6900508212579467
# with Surrogate Model GP
# {'model': LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         feature_fraction=0.44467435447482206, importance_type='split',
#         is_unbalance=False, learning_rate=0.01, max_bin=10000,
#         max_depth=-1, min_child_samples=20, min_child_weight=0.001,
#         min_split_gain=0.0, n_estimators=373, n_jobs=-1, nthread=-1,
#         num_leaves=31, objective='binary', random_state=None,
#         reg_alpha=0.00010170874690891423, reg_lambda=1e-09, seed=0,
#         silent=True, subsample=1.0, subsample_for_bin=200000,
#         subsample_freq=0),
#  'model__boosting_type': 'gbdt',
#  'model__feature_fraction': 0.44467435447482206,
#  'model__is_unbalance': False,
#  'model__learning_rate': 0.01,
#  'model__max_bin': 10000,
#  'model__n_estimators': 373,
#  'model__reg_alpha': 0.00010170874690891423,
#  'model__reg_lambda': 1e-09}
# End   [optimise_step]. Time elapsed: 90.06 sec.
#
# >>>>>> npoints: 5
#
# Start [optimise_step]:
# INFO  [07-20 20:19:05] Start turning Hyperparameters ....
#
# >>> Categorical Features have encoded with :{'strategy': 'label_encoding'}
#
# >>> Numerical Features have encoded with :Scaler
#
# INFO  [07-20 20:19:05] start tuning  with Surrogate Model:GP...
#
# took CPU Time: 60.0s,clock time: 50.0, candidates checked:40 ,best CV score: 0.68895592 ± 0.01
#
# INFO  [07-20 20:19:54] start tuning  with Surrogate Model:RF...
#
# took CPU Time: 26.0s,clock time: 49.0, candidates checked:40 ,best CV score: 0.69268974 ± 0.0098
#
#
# ######## Congratulations! Here is the Best Parameters: #######
# Best Score is: 0.6926897373868456
# with Surrogate Model RF
# {'model': LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         feature_fraction=0.7515808725135097, importance_type='split',
#         is_unbalance=False, learning_rate=0.1274347139619803, max_bin=8077,
#         max_depth=-1, min_child_samples=20, min_child_weight=0.001,
#         min_split_gain=0.0, n_estimators=39, n_jobs=-1, nthread=-1,
#         num_leaves=31, objective='binary', random_state=None,
#         reg_alpha=0.006108301040179926, reg_lambda=44.80782801012955,
#         seed=0, silent=True, subsample=1.0, subsample_for_bin=200000,
#         subsample_freq=0),
#  'model__boosting_type': 'gbdt',
#  'model__feature_fraction': 0.7515808725135097,
#  'model__is_unbalance': False,
#  'model__learning_rate': 0.1274347139619803,
#  'model__max_bin': 8077,
#  'model__n_estimators': 39,
#  'model__reg_alpha': 0.006108301040179926,
#  'model__reg_lambda': 44.80782801012955}
# End   [optimise_step]. Time elapsed: 98.72 sec.
#
# >>>>>> npoints: 6
#
# Start [optimise_step]:
# INFO  [07-20 20:20:43] Start turning Hyperparameters ....
#
# >>> Categorical Features have encoded with :{'strategy': 'label_encoding'}
#
# >>> Numerical Features have encoded with :Scaler
#
# INFO  [07-20 20:20:43] start tuning  with Surrogate Model:GP...
# took CPU Time: 56.0s,clock time: 55.0, candidates checked:40 ,best CV score: 0.69408098 ± 0.0109
#
# INFO  [07-20 20:21:38] start tuning  with Surrogate Model:RF...
#
# took CPU Time: 26.0s,clock time: 53.0, candidates checked:40 ,best CV score: 0.68356247 ± 0.0045
#
#
# ######## Congratulations! Here is the Best Parameters: #######
# Best Score is: 0.6940809753120538
# with Surrogate Model GP
# {'model': LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         feature_fraction=1.0, importance_type='split', is_unbalance=False,
#         learning_rate=0.01, max_bin=100, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=500, n_jobs=-1, nthread=-1, num_leaves=31,
#         objective='binary', random_state=None,
#         reg_alpha=0.1120090455165699, reg_lambda=9.043771642335978, seed=0,
#         silent=True, subsample=1.0, subsample_for_bin=200000,
#         subsample_freq=0),
#  'model__boosting_type': 'gbdt',
#  'model__feature_fraction': 1.0,
#  'model__is_unbalance': False,
#  'model__learning_rate': 0.01,
#  'model__max_bin': 100,
#  'model__n_estimators': 500,
#  'model__reg_alpha': 0.1120090455165699,
#  'model__reg_lambda': 9.043771642335978}
# End   [optimise_step]. Time elapsed: 107.48 sec.
#
# >>>>>> npoints: 7
#
# Start [optimise_step]:
# INFO  [07-20 20:22:31] Start turning Hyperparameters ....
#
# >>> Categorical Features have encoded with :{'strategy': 'label_encoding'}
#
# >>> Numerical Features have encoded with :Scaler
#
# INFO  [07-20 20:22:31] start tuning  with Surrogate Model:GP...
#
# took CPU Time: 55.0s,clock time: 43.0, candidates checked:40 ,best CV score: 0.69338953 ± 0.0117
#
# INFO  [07-20 20:23:14] start tuning  with Surrogate Model:RF...
#
# took CPU Time: 23.0s,clock time: 59.0, candidates checked:40 ,best CV score: 0.68645839 ± 0.0152
#
#
# ######## Congratulations! Here is the Best Parameters: #######
# Best Score is: 0.6933895330080385
# with Surrogate Model GP
# {'model': LGBMClassifier(boosting_type='dart', class_weight=None, colsample_bytree=1.0,
#         feature_fraction=0.3934491325295981, importance_type='split',
#         is_unbalance=True, learning_rate=0.6285803549901531, max_bin=7850,
#         max_depth=-1, min_child_samples=20, min_child_weight=0.001,
#         min_split_gain=0.0, n_estimators=335, n_jobs=-1, nthread=-1,
#         num_leaves=31, objective='binary', random_state=None,
#         reg_alpha=8.21696992146695e-09, reg_lambda=659.7242559847532,
#         seed=0, silent=True, subsample=1.0, subsample_for_bin=200000,
#         subsample_freq=0),
#  'model__boosting_type': 'dart',
#  'model__feature_fraction': 0.3934491325295981,
#  'model__is_unbalance': True,
#  'model__learning_rate': 0.6285803549901531,
#  'model__max_bin': 7850,
#  'model__n_estimators': 335,
#  'model__reg_alpha': 8.21696992146695e-09,
#  'model__reg_lambda': 659.7242559847532}
# End   [optimise_step]. Time elapsed: 101.67 sec.
#
# >>>>>> npoints: 8
#
# Start [optimise_step]:
# INFO  [07-20 20:24:13] Start turning Hyperparameters ....
#
# >>> Categorical Features have encoded with :{'strategy': 'label_encoding'}
#
# >>> Numerical Features have encoded with :Scaler
#
# INFO  [07-20 20:24:13] start tuning  with Surrogate Model:GP...
#
# took CPU Time: 50.0s,clock time: 47.0, candidates checked:40 ,best CV score: 0.69363298 ± 0.0105
#
# INFO  [07-20 20:25:00] start tuning  with Surrogate Model:RF...
#
# took CPU Time: 25.0s,clock time: 54.0, candidates checked:40 ,best CV score: 0.68121856 ± 0.0059
#
#
# ######## Congratulations! Here is the Best Parameters: #######
# Best Score is: 0.6936329794158248
# with Surrogate Model GP
# {'model': LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         feature_fraction=1.0, importance_type='split', is_unbalance=False,
#         learning_rate=0.1364868974827719, max_bin=10000, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=313, n_jobs=-1, nthread=-1, num_leaves=31,
#         objective='binary', random_state=None,
#         reg_alpha=3.3083265241002806, reg_lambda=1000.0, seed=0,
#         silent=True, subsample=1.0, subsample_for_bin=200000,
#         subsample_freq=0),
#  'model__boosting_type': 'gbdt',
#  'model__feature_fraction': 1.0,
#  'model__is_unbalance': False,
#  'model__learning_rate': 0.1364868974827719,
#  'model__max_bin': 10000,
#  'model__n_estimators': 313,
#  'model__reg_alpha': 3.3083265241002806,
#  'model__reg_lambda': 1000.0}
# End   [optimise_step]. Time elapsed: 101.53 sec.
#
# >>>>>> npoints: 9
#
# Start [optimise_step]:
# INFO  [07-20 20:25:54] Start turning Hyperparameters ....
#
# >>> Categorical Features have encoded with :{'strategy': 'label_encoding'}
#
# >>> Numerical Features have encoded with :Scaler
#
# INFO  [07-20 20:25:54] start tuning  with Surrogate Model:GP...
#
# took CPU Time: 57.0s,clock time: 56.0, candidates checked:40 ,best CV score: 0.69338953 ± 0.0117
#
# INFO  [07-20 20:26:51] start tuning  with Surrogate Model:RF...
#
# took CPU Time: 27.0s,clock time: 44.0, candidates checked:40 ,best CV score: 0.67824858 ± 0.0106
#
#
# ######## Congratulations! Here is the Best Parameters: #######
# Best Score is: 0.6933895330080385
# with Surrogate Model GP
# {'model': LGBMClassifier(boosting_type='dart', class_weight=None, colsample_bytree=1.0,
#         feature_fraction=0.3934491325295981, importance_type='split',
#         is_unbalance=True, learning_rate=0.6285803549901531, max_bin=7850,
#         max_depth=-1, min_child_samples=20, min_child_weight=0.001,
#         min_split_gain=0.0, n_estimators=335, n_jobs=-1, nthread=-1,
#         num_leaves=31, objective='binary', random_state=None,
#         reg_alpha=8.21696992146695e-09, reg_lambda=659.7242559847532,
#         seed=0, silent=True, subsample=1.0, subsample_for_bin=200000,
#         subsample_freq=0),
#  'model__boosting_type': 'dart',
#  'model__feature_fraction': 0.3934491325295981,
#  'model__is_unbalance': True,
#  'model__learning_rate': 0.6285803549901531,
#  'model__max_bin': 7850,
#  'model__n_estimators': 335,
#  'model__reg_alpha': 8.21696992146695e-09,
#  'model__reg_lambda': 659.7242559847532}
# End   [optimise_step]. Time elapsed: 100.05 sec.
#
# >>>>>> npoints: 10
#
# Start [optimise_step]:
# INFO  [07-20 20:27:34] Start turning Hyperparameters ....
#
# >>> Categorical Features have encoded with :{'strategy': 'label_encoding'}
#
# >>> Numerical Features have encoded with :Scaler
#
# INFO  [07-20 20:27:34] start tuning  with Surrogate Model:GP...
#
# took CPU Time: 51.0s,clock time: 42.0, candidates checked:40 ,best CV score: 0.69338953 ± 0.0117
#
# INFO  [07-20 20:28:16] start tuning  with Surrogate Model:RF...
#
# took CPU Time: 23.0s,clock time: 36.0, candidates checked:40 ,best CV score: 0.67824858 ± 0.0106
#
#
# ######## Congratulations! Here is the Best Parameters: #######
# Best Score is: 0.6933895330080385
# with Surrogate Model GP
# {'model': LGBMClassifier(boosting_type='dart', class_weight=None, colsample_bytree=1.0,
#         feature_fraction=0.3934491325295981, importance_type='split',
#         is_unbalance=True, learning_rate=0.6285803549901531, max_bin=7850,
#         max_depth=-1, min_child_samples=20, min_child_weight=0.001,
#         min_split_gain=0.0, n_estimators=335, n_jobs=-1, nthread=-1,
#         num_leaves=31, objective='binary', random_state=None,
#         reg_alpha=8.21696992146695e-09, reg_lambda=659.7242559847532,
#         seed=0, silent=True, subsample=1.0, subsample_for_bin=200000,
#         subsample_freq=0),
#  'model__boosting_type': 'dart',
#  'model__feature_fraction': 0.3934491325295981,
#  'model__is_unbalance': True,
#  'model__learning_rate': 0.6285803549901531,
#  'model__max_bin': 7850,
#  'model__n_estimators': 335,
#  'model__reg_alpha': 8.21696992146695e-09,
#  'model__reg_lambda': 659.7242559847532}
# End   [optimise_step]. Time elapsed: 78.26 sec.
# Dump successful! File Name: jm1_parallel_np_5f_20_eips_20190720202853.json
# Dump successful! File Name: jm1_best_param_5f_20_eips_20190720202903.json

# %%
from sklearn.model_selection import train_test_split
from skopt.space import Real, Categorical, Integer
#from optimisation_fs import Optimiser
from model import Classifier
import pandas as pd
from util import dump_result,load_result

df_train = data['train'] #df_test = data['test']
#df_train = pd.DataFrame(df_train)
y = data['target'] #y_test = data['y_test']

#X_train, X_val,y_train,y_val= train_test_split(df_train,y, test_size=0.6,random_state=42)
np_best_param = {}
np_results = {}
for n in range(1,11):
    nname = "npoints_"+str(n)
    print("")
    print(">>>>>> npoints:",n )
    optimiser = Optimiser(verbose=0,n_folds=5,parallel_strategy=True)
    search_space_LGB = Classifier(strategy = "LightGBM").get_search_spaces(need_feature_selection=False)
    search_space_SVC = Classifier(strategy = "SVC").get_search_spaces(need_feature_selection=False)

    best_param,results = optimiser.optimise_step( space = [(search_space_LGB,40),(search_space_SVC,40)],
                                                  df_train=df_train,
                                                  df_target=y,
                                                  set_callbacks=True,
                                                  npoints=n)
    
    np_best_param[nname] = best_param
    np_results[nname] = results
    
dump_result(np_results,"parallel_np_5f_40_eips",save_with_time=True)
dump_result(np_best_param,"best_param_5f_40_eips",save_with_time=True)
# Out:
# >>>>>> npoints: 1
#
# Start [optimise_step]:
# INFO  [07-20 20:32:17] Start turning Hyperparameters ....
#
# >>> Categorical Features have encoded with :{'strategy': 'label_encoding'}
#
# >>> Numerical Features have encoded with :Scaler
#
# INFO  [07-20 20:32:17] start tuning  with Surrogate Model:GP...
#
# took CPU Time: 286.0s,clock time: 174.0, candidates checked:72 ,best CV score: 0.69285553 ± 0.0117
#
# INFO  [07-20 20:35:11] start tuning  with Surrogate Model:RF...
#
# took CPU Time: 135.0s,clock time: 168.0, candidates checked:80 ,best CV score: 0.69517059 ± 0.0128
#
#
# ######## Congratulations! Here is the Best Parameters: #######
# Best Score is: 0.6951705862224818
# with Surrogate Model RF
# {'model': LGBMClassifier(boosting_type='dart', class_weight=None, colsample_bytree=1.0,
#         feature_fraction=0.6269410062950892, importance_type='split',
#         is_unbalance=True, learning_rate=0.7549437155154509, max_bin=8701,
#         max_depth=-1, min_child_samples=20, min_child_weight=0.001,
#         min_split_gain=0.0, n_estimators=69, n_jobs=-1, nthread=-1,
#         num_leaves=31, objective='binary', random_state=None,
#         reg_alpha=1.4726135556206274e-07, reg_lambda=404.6407085815774,
#         seed=0, silent=True, subsample=1.0, subsample_for_bin=200000,
#         subsample_freq=0),
#  'model__boosting_type': 'dart',
#  'model__feature_fraction': 0.6269410062950892,
#  'model__is_unbalance': True,
#  'model__learning_rate': 0.7549437155154509,
#  'model__max_bin': 8701,
#  'model__n_estimators': 69,
#  'model__reg_alpha': 1.4726135556206274e-07,
#  'model__reg_lambda': 404.6407085815774}
# End   [optimise_step]. Time elapsed: 341.99 sec.
#
# >>>>>> npoints: 2
#
# Start [optimise_step]:
# INFO  [07-20 20:37:59] Start turning Hyperparameters ....
#
# >>> Categorical Features have encoded with :{'strategy': 'label_encoding'}
#
# >>> Numerical Features have encoded with :Scaler
#
# INFO  [07-20 20:37:59] start tuning  with Surrogate Model:GP...
#
# took CPU Time: 188.0s,clock time: 163.0, candidates checked:58 ,best CV score: 0.69414795 ± 0.0132
#
# INFO  [07-20 20:40:42] start tuning  with Surrogate Model:RF...
#
# took CPU Time: 111.0s,clock time: 151.0, candidates checked:80 ,best CV score: 0.69107334 ± 0.0115
#
#
# ######## Congratulations! Here is the Best Parameters: #######
# Best Score is: 0.6941479487935117
# with Surrogate Model GP
# {'model': LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         feature_fraction=1.0, importance_type='split', is_unbalance=True,
#         learning_rate=0.01, max_bin=9282, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=401, n_jobs=-1, nthread=-1, num_leaves=31,
#         objective='binary', random_state=None,
#         reg_alpha=2.6614042651693355e-07, reg_lambda=53.654801586986494,
#         seed=0, silent=True, subsample=1.0, subsample_for_bin=200000,
#         subsample_freq=0),
#  'model__boosting_type': 'gbdt',
#  'model__feature_fraction': 1.0,
#  'model__is_unbalance': True,
#  'model__learning_rate': 0.01,
#  'model__max_bin': 9282,
#  'model__n_estimators': 401,
#  'model__reg_alpha': 2.6614042651693355e-07,
#  'model__reg_lambda': 53.654801586986494}
# End   [optimise_step]. Time elapsed: 314.17 sec.
#
# >>>>>> npoints: 3
#
# Start [optimise_step]:
# INFO  [07-20 20:43:14] Start turning Hyperparameters ....
#
# >>> Categorical Features have encoded with :{'strategy': 'label_encoding'}
#
# >>> Numerical Features have encoded with :Scaler
#
# INFO  [07-20 20:43:14] start tuning  with Surrogate Model:GP...
#
# took CPU Time: 225.0s,clock time: 180.0, candidates checked:80 ,best CV score: 0.69038989 ± 0.0155
#
# INFO  [07-20 20:46:13] start tuning  with Surrogate Model:RF...
#
# took CPU Time: 95.0s,clock time: 110.0, candidates checked:80 ,best CV score: 0.69238364 ± 0.0137
#
#
# ######## Congratulations! Here is the Best Parameters: #######
# Best Score is: 0.692383644490261
# with Surrogate Model RF
# {'model': LGBMClassifier(boosting_type='dart', class_weight=None, colsample_bytree=1.0,
#         feature_fraction=0.7323482856973, importance_type='split',
#         is_unbalance=True, learning_rate=0.12025137196124303, max_bin=1080,
#         max_depth=-1, min_child_samples=20, min_child_weight=0.001,
#         min_split_gain=0.0, n_estimators=449, n_jobs=-1, nthread=-1,
#         num_leaves=31, objective='binary', random_state=None,
#         reg_alpha=23.356308774867575, reg_lambda=1.6296774452630643e-09,
#         seed=0, silent=True, subsample=1.0, subsample_for_bin=200000,
#         subsample_freq=0),
#  'model__boosting_type': 'dart',
#  'model__feature_fraction': 0.7323482856973,
#  'model__is_unbalance': True,
#  'model__learning_rate': 0.12025137196124303,
#  'model__max_bin': 1080,
#  'model__n_estimators': 449,
#  'model__reg_alpha': 23.356308774867575,
#  'model__reg_lambda': 1.6296774452630643e-09}
# End   [optimise_step]. Time elapsed: 289.52 sec.
#
# >>>>>> npoints: 4
#
# Start [optimise_step]:
# INFO  [07-20 20:48:03] Start turning Hyperparameters ....
#
# >>> Categorical Features have encoded with :{'strategy': 'label_encoding'}
#
# >>> Numerical Features have encoded with :Scaler
#
# INFO  [07-20 20:48:03] start tuning  with Surrogate Model:GP...
#
# took CPU Time: 191.0s,clock time: 163.0, candidates checked:80 ,best CV score: 0.69005082 ± 0.0087
#
# INFO  [07-20 20:50:46] start tuning  with Surrogate Model:RF...
#
# took CPU Time: 58.0s,clock time: 66.0, candidates checked:80 ,best CV score: 0.69013916 ± 0.0138
#
#
# ######## Congratulations! Here is the Best Parameters: #######
# Best Score is: 0.6901391615539519
# with Surrogate Model RF
# {'model': LGBMClassifier(boosting_type='dart', class_weight=None, colsample_bytree=1.0,
#         feature_fraction=0.8218360353418352, importance_type='split',
#         is_unbalance=True, learning_rate=0.07869961647382434, max_bin=827,
#         max_depth=-1, min_child_samples=20, min_child_weight=0.001,
#         min_split_gain=0.0, n_estimators=69, n_jobs=-1, nthread=-1,
#         num_leaves=31, objective='binary', random_state=None,
#         reg_alpha=1.3732869538124257, reg_lambda=1.5347568611978068e-06,
#         seed=0, silent=True, subsample=1.0, subsample_for_bin=200000,
#         subsample_freq=0),
#  'model__boosting_type': 'dart',
#  'model__feature_fraction': 0.8218360353418352,
#  'model__is_unbalance': True,
#  'model__learning_rate': 0.07869961647382434,
#  'model__max_bin': 827,
#  'model__n_estimators': 69,
#  'model__reg_alpha': 1.3732869538124257,
#  'model__reg_lambda': 1.5347568611978068e-06}
# End   [optimise_step]. Time elapsed: 229.17 sec.
#
# >>>>>> npoints: 5
#
# Start [optimise_step]:
# INFO  [07-20 20:51:52] Start turning Hyperparameters ....
#
# >>> Categorical Features have encoded with :{'strategy': 'label_encoding'}
#
# >>> Numerical Features have encoded with :Scaler
#
# INFO  [07-20 20:51:52] start tuning  with Surrogate Model:GP...
#
# took CPU Time: 134.0s,clock time: 140.0, candidates checked:70 ,best CV score: 0.69086734 ± 0.0075
#
# INFO  [07-20 20:54:12] start tuning  with Surrogate Model:RF...
#
# took CPU Time: 57.0s,clock time: 75.0, candidates checked:80 ,best CV score: 0.69268974 ± 0.0098
#
#
# ######## Congratulations! Here is the Best Parameters: #######
# Best Score is: 0.6926897373868456
# with Surrogate Model RF
# {'model': LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         feature_fraction=0.7515808725135097, importance_type='split',
#         is_unbalance=False, learning_rate=0.1274347139619803, max_bin=8077,
#         max_depth=-1, min_child_samples=20, min_child_weight=0.001,
#         min_split_gain=0.0, n_estimators=39, n_jobs=-1, nthread=-1,
#         num_leaves=31, objective='binary', random_state=None,
#         reg_alpha=0.006108301040179926, reg_lambda=44.80782801012955,
#         seed=0, silent=True, subsample=1.0, subsample_for_bin=200000,
#         subsample_freq=0),
#  'model__boosting_type': 'gbdt',
#  'model__feature_fraction': 0.7515808725135097,
#  'model__is_unbalance': False,
#  'model__learning_rate': 0.1274347139619803,
#  'model__max_bin': 8077,
#  'model__n_estimators': 39,
#  'model__reg_alpha': 0.006108301040179926,
#  'model__reg_lambda': 44.80782801012955}
# End   [optimise_step]. Time elapsed: 215.27 sec.
#
# >>>>>> npoints: 6
#
# Start [optimise_step]:
# INFO  [07-20 20:55:28] Start turning Hyperparameters ....
#
# >>> Categorical Features have encoded with :{'strategy': 'label_encoding'}
#
# >>> Numerical Features have encoded with :Scaler
#
# INFO  [07-20 20:55:28] start tuning  with Surrogate Model:GP...
# took CPU Time: 179.0s,clock time: 166.0, candidates checked:80 ,best CV score: 0.69630667 ± 0.0129
#
# INFO  [07-20 20:58:13] start tuning  with Surrogate Model:RF...
#
# took CPU Time: 53.0s,clock time: 78.0, candidates checked:80 ,best CV score: 0.68356247 ± 0.0045
#
#
# ######## Congratulations! Here is the Best Parameters: #######
# Best Score is: 0.6963066728484417
# with Surrogate Model GP
# {'model': LGBMClassifier(boosting_type='dart', class_weight=None, colsample_bytree=1.0,
#         feature_fraction=1.0, importance_type='split', is_unbalance=False,
#         learning_rate=1.0, max_bin=100, max_depth=-1, min_child_samples=20,
#         min_child_weight=0.001, min_split_gain=0.0, n_estimators=500,
#         n_jobs=-1, nthread=-1, num_leaves=31, objective='binary',
#         random_state=None, reg_alpha=1e-09, reg_lambda=1000.0, seed=0,
#         silent=True, subsample=1.0, subsample_for_bin=200000,
#         subsample_freq=0),
#  'model__boosting_type': 'dart',
#  'model__feature_fraction': 1.0,
#  'model__is_unbalance': False,
#  'model__learning_rate': 1.0,
#  'model__max_bin': 100,
#  'model__n_estimators': 500,
#  'model__reg_alpha': 1e-09,
#  'model__reg_lambda': 1000.0}
# End   [optimise_step]. Time elapsed: 243.36 sec.
#
# >>>>>> npoints: 7
#
# Start [optimise_step]:
# INFO  [07-20 20:59:31] Start turning Hyperparameters ....
#
# >>> Categorical Features have encoded with :{'strategy': 'label_encoding'}
#
# >>> Numerical Features have encoded with :Scaler
#
# INFO  [07-20 20:59:31] start tuning  with Surrogate Model:GP...
#
# took CPU Time: 166.0s,clock time: 144.0, candidates checked:80 ,best CV score: 0.69531304 ± 0.0098
#
# INFO  [07-20 21:01:55] start tuning  with Surrogate Model:RF...
#
# took CPU Time: 50.0s,clock time: 84.0, candidates checked:80 ,best CV score: 0.68798042 ± 0.0088
#
#
# ######## Congratulations! Here is the Best Parameters: #######
# Best Score is: 0.695313038231781
# with Surrogate Model GP
# {'model': LGBMClassifier(boosting_type='dart', class_weight=None, colsample_bytree=1.0,
#         feature_fraction=0.5638663724893178, importance_type='split',
#         is_unbalance=False, learning_rate=1.0, max_bin=100, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=500, n_jobs=-1, nthread=-1, num_leaves=31,
#         objective='binary', random_state=None, reg_alpha=1e-09,
#         reg_lambda=1000.0, seed=0, silent=True, subsample=1.0,
#         subsample_for_bin=200000, subsample_freq=0),
#  'model__boosting_type': 'dart',
#  'model__feature_fraction': 0.5638663724893178,
#  'model__is_unbalance': False,
#  'model__learning_rate': 1.0,
#  'model__max_bin': 100,
#  'model__n_estimators': 500,
#  'model__reg_alpha': 1e-09,
#  'model__reg_lambda': 1000.0}
# End   [optimise_step]. Time elapsed: 228.11 sec.
#
# >>>>>> npoints: 8
#
# Start [optimise_step]:
# INFO  [07-20 21:03:19] Start turning Hyperparameters ....
#
# >>> Categorical Features have encoded with :{'strategy': 'label_encoding'}
#
# >>> Numerical Features have encoded with :Scaler
#
# INFO  [07-20 21:03:19] start tuning  with Surrogate Model:GP...
#
# took CPU Time: 150.0s,clock time: 114.0, candidates checked:80 ,best CV score: 0.69415188 ± 0.0088
#
# INFO  [07-20 21:05:13] start tuning  with Surrogate Model:RF...
#
# took CPU Time: 85.0s,clock time: 130.0, candidates checked:80 ,best CV score: 0.69303468 ± 0.0144
#
#
# ######## Congratulations! Here is the Best Parameters: #######
# Best Score is: 0.6941518773612797
# with Surrogate Model GP
# {'model': LGBMClassifier(boosting_type='dart', class_weight=None, colsample_bytree=1.0,
#         feature_fraction=0.6536984466079172, importance_type='split',
#         is_unbalance=False, learning_rate=0.8837202053873043,
#         max_bin=10000, max_depth=-1, min_child_samples=20,
#         min_child_weight=0.001, min_split_gain=0.0, n_estimators=298,
#         n_jobs=-1, nthread=-1, num_leaves=31, objective='binary',
#         random_state=None, reg_alpha=3.1148696464382652e-09,
#         reg_lambda=1000.0, seed=0, silent=True, subsample=1.0,
#         subsample_for_bin=200000, subsample_freq=0),
#  'model__boosting_type': 'dart',
#  'model__feature_fraction': 0.6536984466079172,
#  'model__is_unbalance': False,
#  'model__learning_rate': 0.8837202053873043,
#  'model__max_bin': 10000,
#  'model__n_estimators': 298,
#  'model__reg_alpha': 3.1148696464382652e-09,
#  'model__reg_lambda': 1000.0}
# End   [optimise_step]. Time elapsed: 243.92 sec.
#
# >>>>>> npoints: 9
#
# Start [optimise_step]:
# INFO  [07-20 21:07:23] Start turning Hyperparameters ....
#
# >>> Categorical Features have encoded with :{'strategy': 'label_encoding'}
#
# >>> Numerical Features have encoded with :Scaler
#
# INFO  [07-20 21:07:23] start tuning  with Surrogate Model:GP...
#
# took CPU Time: 163.0s,clock time: 149.0, candidates checked:80 ,best CV score: 0.69338953 ± 0.0117
#
# INFO  [07-20 21:09:52] start tuning  with Surrogate Model:RF...
#
# took CPU Time: 50.0s,clock time: 64.0, candidates checked:80 ,best CV score: 0.67824858 ± 0.0106
#
#
# ######## Congratulations! Here is the Best Parameters: #######
# Best Score is: 0.6933895330080385
# with Surrogate Model GP
# {'model': LGBMClassifier(boosting_type='dart', class_weight=None, colsample_bytree=1.0,
#         feature_fraction=0.3934491325295981, importance_type='split',
#         is_unbalance=True, learning_rate=0.6285803549901531, max_bin=7850,
#         max_depth=-1, min_child_samples=20, min_child_weight=0.001,
#         min_split_gain=0.0, n_estimators=335, n_jobs=-1, nthread=-1,
#         num_leaves=31, objective='binary', random_state=None,
#         reg_alpha=8.21696992146695e-09, reg_lambda=659.7242559847532,
#         seed=0, silent=True, subsample=1.0, subsample_for_bin=200000,
#         subsample_freq=0),
#  'model__boosting_type': 'dart',
#  'model__feature_fraction': 0.3934491325295981,
#  'model__is_unbalance': True,
#  'model__learning_rate': 0.6285803549901531,
#  'model__max_bin': 7850,
#  'model__n_estimators': 335,
#  'model__reg_alpha': 8.21696992146695e-09,
#  'model__reg_lambda': 659.7242559847532}
# End   [optimise_step]. Time elapsed: 212.87 sec.
#
# >>>>>> npoints: 10
#
# Start [optimise_step]:
# INFO  [07-20 21:10:56] Start turning Hyperparameters ....
#
# >>> Categorical Features have encoded with :{'strategy': 'label_encoding'}
#
# >>> Numerical Features have encoded with :Scaler
#
# INFO  [07-20 21:10:56] start tuning  with Surrogate Model:GP...
#
# took CPU Time: 165.0s,clock time: 145.0, candidates checked:80 ,best CV score: 0.6955799 ± 0.0114
#
# INFO  [07-20 21:13:21] start tuning  with Surrogate Model:RF...
#
# took CPU Time: 46.0s,clock time: 71.0, candidates checked:80 ,best CV score: 0.67824858 ± 0.0106
#
#
# ######## Congratulations! Here is the Best Parameters: #######
# Best Score is: 0.6955799046049255
# with Surrogate Model GP
# {'model': LGBMClassifier(boosting_type='dart', class_weight=None, colsample_bytree=1.0,
#         feature_fraction=0.9607740051068241, importance_type='split',
#         is_unbalance=False, learning_rate=0.8788203853954335, max_bin=3171,
#         max_depth=-1, min_child_samples=20, min_child_weight=0.001,
#         min_split_gain=0.0, n_estimators=500, n_jobs=-1, nthread=-1,
#         num_leaves=31, objective='binary', random_state=None,
#         reg_alpha=1e-09, reg_lambda=1000.0, seed=0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0),
#  'model__boosting_type': 'dart',
#  'model__feature_fraction': 0.9607740051068241,
#  'model__is_unbalance': False,
#  'model__learning_rate': 0.8788203853954335,
#  'model__max_bin': 3171,
#  'model__n_estimators': 500,
#  'model__reg_alpha': 1e-09,
#  'model__reg_lambda': 1000.0}
# End   [optimise_step]. Time elapsed: 216.74 sec.
# Dump successful! File Name: jm1_parallel_np_5f_40_eips_20190720211433.json
# Dump successful! File Name: jm1_best_param_5f_40_eips_20190720211455.json

# %%
from sklearn.model_selection import train_test_split
from skopt.space import Real, Categorical, Integer
#from optimisation_fs import Optimiser
from model import Classifier
import pandas as pd
from util import dump_result,load_result

df_train = data['train'] #df_test = data['test']
#df_train = pd.DataFrame(df_train)
y = data['target'] #y_test = data['y_test']

#X_train, X_val,y_train,y_val= train_test_split(df_train,y, test_size=0.6,random_state=42)
np_best_param = {}
np_results = {}
for n in range(1,11):
    nname = "npoints_"+str(n)
    print("")
    print(">>>>>> npoints:",n )
    optimiser = Optimiser(verbose=0,n_folds=5,parallel_strategy=True)
    search_space_LGB = Classifier(strategy = "LightGBM").get_search_spaces(need_feature_selection=False)
    search_space_SVC = Classifier(strategy = "SVC").get_search_spaces(need_feature_selection=False)

    best_param,results = optimiser.optimise_step( space = [(search_space_LGB,100),(search_space_SVC,100)],
                                                  df_train=df_train,
                                                  df_target=y,
                                                  set_callbacks=True,
                                                  npoints=n)
    
    np_best_param[nname] = best_param
    np_results[nname] = results
    
dump_result(np_results,"parallel_np_5f_100_eips",save_with_time=False)
#dump_result(np_best_param,"best_param_5f_40_eips",save_with_time=True)
# Out:
# >>>>>> npoints: 1
#
# Start [optimise_step]:
# INFO  [07-20 21:38:22] Start turning Hyperparameters ....
#
# >>> Categorical Features have encoded with :{'strategy': 'label_encoding'}
#
# >>> Numerical Features have encoded with :Scaler
#
# INFO  [07-20 21:38:22] start tuning  with Surrogate Model:GP...
#
# took CPU Time: 735.0s,clock time: 292.0, candidates checked:77 ,best CV score: 0.69651048 ± 0.0122
#
# INFO  [07-20 21:43:15] start tuning  with Surrogate Model:RF...
#
# took CPU Time: 302.0s,clock time: 289.0, candidates checked:144 ,best CV score: 0.69517059 ± 0.0128
#
#
# ######## Congratulations! Here is the Best Parameters: #######
# Best Score is: 0.6965104818572971
# with Surrogate Model GP
# {'model': LGBMClassifier(boosting_type='dart', class_weight=None, colsample_bytree=1.0,
#         feature_fraction=1.0, importance_type='split', is_unbalance=False,
#         learning_rate=1.0, max_bin=100, max_depth=-1, min_child_samples=20,
#         min_child_weight=0.001, min_split_gain=0.0, n_estimators=500,
#         n_jobs=-1, nthread=-1, num_leaves=31, objective='binary',
#         random_state=None, reg_alpha=0.01387580110504507,
#         reg_lambda=1000.0, seed=0, silent=True, subsample=1.0,
#         subsample_for_bin=200000, subsample_freq=0),
#  'model__boosting_type': 'dart',
#  'model__feature_fraction': 1.0,
#  'model__is_unbalance': False,
#  'model__learning_rate': 1.0,
#  'model__max_bin': 100,
#  'model__n_estimators': 500,
#  'model__reg_alpha': 0.01387580110504507,
#  'model__reg_lambda': 1000.0}
# End   [optimise_step]. Time elapsed: 580.95 sec.
#
# >>>>>> npoints: 2
#
# Start [optimise_step]:
# INFO  [07-20 21:48:04] Start turning Hyperparameters ....
#
# >>> Categorical Features have encoded with :{'strategy': 'label_encoding'}
#
# >>> Numerical Features have encoded with :Scaler
#
# INFO  [07-20 21:48:04] start tuning  with Surrogate Model:GP...
#
# took CPU Time: 481.0s,clock time: 286.0, candidates checked:74 ,best CV score: 0.69414795 ± 0.0132
#
# INFO  [07-20 21:52:49] start tuning  with Surrogate Model:RF...
#
# took CPU Time: 245.0s,clock time: 285.0, candidates checked:162 ,best CV score: 0.69282324 ± 0.0118
#
#
# ######## Congratulations! Here is the Best Parameters: #######
# Best Score is: 0.6941479487935117
# with Surrogate Model GP
# {'model': LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         feature_fraction=1.0, importance_type='split', is_unbalance=True,
#         learning_rate=0.01, max_bin=9282, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=401, n_jobs=-1, nthread=-1, num_leaves=31,
#         objective='binary', random_state=None,
#         reg_alpha=2.6614042651693355e-07, reg_lambda=53.654801586986494,
#         seed=0, silent=True, subsample=1.0, subsample_for_bin=200000,
#         subsample_freq=0),
#  'model__boosting_type': 'gbdt',
#  'model__feature_fraction': 1.0,
#  'model__is_unbalance': True,
#  'model__learning_rate': 0.01,
#  'model__max_bin': 9282,
#  'model__n_estimators': 401,
#  'model__reg_alpha': 2.6614042651693355e-07,
#  'model__reg_lambda': 53.654801586986494}
# End   [optimise_step]. Time elapsed: 570.44 sec.
#
# >>>>>> npoints: 3
#
# Start [optimise_step]:
# INFO  [07-20 21:57:34] Start turning Hyperparameters ....
#
# >>> Categorical Features have encoded with :{'strategy': 'label_encoding'}
#
# >>> Numerical Features have encoded with :Scaler
#
# INFO  [07-20 21:57:34] start tuning  with Surrogate Model:GP...
#
# took CPU Time: 337.0s,clock time: 286.0, candidates checked:72 ,best CV score: 0.69038989 ± 0.0155
#
# INFO  [07-20 22:02:20] start tuning  with Surrogate Model:RF...
#
# took CPU Time: 207.0s,clock time: 272.0, candidates checked:151 ,best CV score: 0.69238364 ± 0.0137
#
#
# ######## Congratulations! Here is the Best Parameters: #######
# Best Score is: 0.692383644490261
# with Surrogate Model RF
# {'model': LGBMClassifier(boosting_type='dart', class_weight=None, colsample_bytree=1.0,
#         feature_fraction=0.7323482856973, importance_type='split',
#         is_unbalance=True, learning_rate=0.12025137196124303, max_bin=1080,
#         max_depth=-1, min_child_samples=20, min_child_weight=0.001,
#         min_split_gain=0.0, n_estimators=449, n_jobs=-1, nthread=-1,
#         num_leaves=31, objective='binary', random_state=None,
#         reg_alpha=23.356308774867575, reg_lambda=1.6296774452630643e-09,
#         seed=0, silent=True, subsample=1.0, subsample_for_bin=200000,
#         subsample_freq=0),
#  'model__boosting_type': 'dart',
#  'model__feature_fraction': 0.7323482856973,
#  'model__is_unbalance': True,
#  'model__learning_rate': 0.12025137196124303,
#  'model__max_bin': 1080,
#  'model__n_estimators': 449,
#  'model__reg_alpha': 23.356308774867575,
#  'model__reg_lambda': 1.6296774452630643e-09}
# End   [optimise_step]. Time elapsed: 557.97 sec.
#
# >>>>>> npoints: 4
#
# Start [optimise_step]:
# INFO  [07-20 22:06:52] Start turning Hyperparameters ....
#
# >>> Categorical Features have encoded with :{'strategy': 'label_encoding'}
#
# >>> Numerical Features have encoded with :Scaler
#
# INFO  [07-20 22:06:52] start tuning  with Surrogate Model:GP...
#
# took CPU Time: 346.0s,clock time: 273.0, candidates checked:76 ,best CV score: 0.69262167 ± 0.0102
#
# INFO  [07-20 22:11:25] start tuning  with Surrogate Model:RF...
#
# took CPU Time: 155.0s,clock time: 191.0, candidates checked:200 ,best CV score: 0.69430023 ± 0.0119
#
#
# ######## Congratulations! Here is the Best Parameters: #######
# Best Score is: 0.6943002332341371
# with Surrogate Model RF
# {'model': LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         feature_fraction=0.7414606369713801, importance_type='split',
#         is_unbalance=True, learning_rate=0.22302453347443818, max_bin=5523,
#         max_depth=-1, min_child_samples=20, min_child_weight=0.001,
#         min_split_gain=0.0, n_estimators=84, n_jobs=-1, nthread=-1,
#         num_leaves=31, objective='binary', random_state=None,
#         reg_alpha=0.058935188661109375, reg_lambda=357.0489897353352,
#         seed=0, silent=True, subsample=1.0, subsample_for_bin=200000,
#         subsample_freq=0),
#  'model__boosting_type': 'gbdt',
#  'model__feature_fraction': 0.7414606369713801,
#  'model__is_unbalance': True,
#  'model__learning_rate': 0.22302453347443818,
#  'model__max_bin': 5523,
#  'model__n_estimators': 84,
#  'model__reg_alpha': 0.058935188661109375,
#  'model__reg_lambda': 357.0489897353352}
# End   [optimise_step]. Time elapsed: 464.30 sec.
#
# >>>>>> npoints: 5
#
# Start [optimise_step]:
# INFO  [07-20 22:14:36] Start turning Hyperparameters ....
#
# >>> Categorical Features have encoded with :{'strategy': 'label_encoding'}
#
# >>> Numerical Features have encoded with :Scaler
#
# INFO  [07-20 22:14:36] start tuning  with Surrogate Model:GP...
#
# took CPU Time: 395.0s,clock time: 278.0, candidates checked:85 ,best CV score: 0.69364235 ± 0.0136
#
# INFO  [07-20 22:19:14] start tuning  with Surrogate Model:RF...
#
# took CPU Time: 145.0s,clock time: 199.0, candidates checked:200 ,best CV score: 0.69268974 ± 0.0098
#
#
# ######## Congratulations! Here is the Best Parameters: #######
# Best Score is: 0.6936423532987585
# with Surrogate Model GP
# {'model': LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         feature_fraction=1.0, importance_type='split', is_unbalance=True,
#         learning_rate=0.01, max_bin=8459, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=485, n_jobs=-1, nthread=-1, num_leaves=31,
#         objective='binary', random_state=None,
#         reg_alpha=12.761483360102071, reg_lambda=6.61565122919659e-07,
#         seed=0, silent=True, subsample=1.0, subsample_for_bin=200000,
#         subsample_freq=0),
#  'model__boosting_type': 'gbdt',
#  'model__feature_fraction': 1.0,
#  'model__is_unbalance': True,
#  'model__learning_rate': 0.01,
#  'model__max_bin': 8459,
#  'model__n_estimators': 485,
#  'model__reg_alpha': 12.761483360102071,
#  'model__reg_lambda': 6.61565122919659e-07}
# End   [optimise_step]. Time elapsed: 477.54 sec.
#
# >>>>>> npoints: 6
#
# Start [optimise_step]:
# INFO  [07-20 22:22:34] Start turning Hyperparameters ....
#
# >>> Categorical Features have encoded with :{'strategy': 'label_encoding'}
#
# >>> Numerical Features have encoded with :Scaler
#
# INFO  [07-20 22:22:34] start tuning  with Surrogate Model:GP...
# took CPU Time: 297.0s,clock time: 270.0, candidates checked:78 ,best CV score: 0.6963241 ± 0.0094
#
# INFO  [07-20 22:27:04] start tuning  with Surrogate Model:RF...
#
# took CPU Time: 151.0s,clock time: 238.0, candidates checked:200 ,best CV score: 0.69025525 ± 0.0077
#
#
# ######## Congratulations! Here is the Best Parameters: #######
# Best Score is: 0.6963241029295401
# with Surrogate Model GP
# {'model': LGBMClassifier(boosting_type='dart', class_weight=None, colsample_bytree=1.0,
#         feature_fraction=0.6064672248688228, importance_type='split',
#         is_unbalance=False, learning_rate=1.0, max_bin=100, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=341, n_jobs=-1, nthread=-1, num_leaves=31,
#         objective='binary', random_state=None, reg_alpha=1e-09,
#         reg_lambda=1000.0, seed=0, silent=True, subsample=1.0,
#         subsample_for_bin=200000, subsample_freq=0),
#  'model__boosting_type': 'dart',
#  'model__feature_fraction': 0.6064672248688228,
#  'model__is_unbalance': False,
#  'model__learning_rate': 1.0,
#  'model__max_bin': 100,
#  'model__n_estimators': 341,
#  'model__reg_alpha': 1e-09,
#  'model__reg_lambda': 1000.0}
# End   [optimise_step]. Time elapsed: 508.42 sec.
#
# >>>>>> npoints: 7
#
# Start [optimise_step]:
# INFO  [07-20 22:31:02] Start turning Hyperparameters ....
#
# >>> Categorical Features have encoded with :{'strategy': 'label_encoding'}
#
# >>> Numerical Features have encoded with :Scaler
#
# INFO  [07-20 22:31:02] start tuning  with Surrogate Model:GP...
#
# took CPU Time: 474.0s,clock time: 287.0, candidates checked:98 ,best CV score: 0.69531304 ± 0.0098
#
# INFO  [07-20 22:35:49] start tuning  with Surrogate Model:RF...
#
# took CPU Time: 137.0s,clock time: 269.0, candidates checked:142 ,best CV score: 0.69276031 ± 0.0133
#
#
# ######## Congratulations! Here is the Best Parameters: #######
# Best Score is: 0.695313038231781
# with Surrogate Model GP
# {'model': LGBMClassifier(boosting_type='dart', class_weight=None, colsample_bytree=1.0,
#         feature_fraction=0.5638663724893178, importance_type='split',
#         is_unbalance=False, learning_rate=1.0, max_bin=100, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=500, n_jobs=-1, nthread=-1, num_leaves=31,
#         objective='binary', random_state=None, reg_alpha=1e-09,
#         reg_lambda=1000.0, seed=0, silent=True, subsample=1.0,
#         subsample_for_bin=200000, subsample_freq=0),
#  'model__boosting_type': 'dart',
#  'model__feature_fraction': 0.5638663724893178,
#  'model__is_unbalance': False,
#  'model__learning_rate': 1.0,
#  'model__max_bin': 100,
#  'model__n_estimators': 500,
#  'model__reg_alpha': 1e-09,
#  'model__reg_lambda': 1000.0}
# End   [optimise_step]. Time elapsed: 556.34 sec.
#
# >>>>>> npoints: 8
#
# Start [optimise_step]:
# INFO  [07-20 22:40:19] Start turning Hyperparameters ....
#
# >>> Categorical Features have encoded with :{'strategy': 'label_encoding'}
#
# >>> Numerical Features have encoded with :Scaler
#
# INFO  [07-20 22:40:19] start tuning  with Surrogate Model:GP...
#
# took CPU Time: 455.0s,clock time: 296.0, candidates checked:104 ,best CV score: 0.69582584 ± 0.0098
#
# INFO  [07-20 22:45:15] start tuning  with Surrogate Model:RF...
#
# took CPU Time: 148.0s,clock time: 266.0, candidates checked:164 ,best CV score: 0.69303468 ± 0.0144
#
#
# ######## Congratulations! Here is the Best Parameters: #######
# Best Score is: 0.6958258350720382
# with Surrogate Model GP
# {'model': LGBMClassifier(boosting_type='dart', class_weight=None, colsample_bytree=1.0,
#         feature_fraction=0.561807301183261, importance_type='split',
#         is_unbalance=False, learning_rate=0.6659245428255507, max_bin=100,
#         max_depth=-1, min_child_samples=20, min_child_weight=0.001,
#         min_split_gain=0.0, n_estimators=500, n_jobs=-1, nthread=-1,
#         num_leaves=31, objective='binary', random_state=None,
#         reg_alpha=1.1761233204883907e-07, reg_lambda=1000.0, seed=0,
#         silent=True, subsample=1.0, subsample_for_bin=200000,
#         subsample_freq=0),
#  'model__boosting_type': 'dart',
#  'model__feature_fraction': 0.561807301183261,
#  'model__is_unbalance': False,
#  'model__learning_rate': 0.6659245428255507,
#  'model__max_bin': 100,
#  'model__n_estimators': 500,
#  'model__reg_alpha': 1.1761233204883907e-07,
#  'model__reg_lambda': 1000.0}
# End   [optimise_step]. Time elapsed: 562.05 sec.
#
# >>>>>> npoints: 9
#
# Start [optimise_step]:
# INFO  [07-20 22:49:41] Start turning Hyperparameters ....
#
# >>> Categorical Features have encoded with :{'strategy': 'label_encoding'}
#
# >>> Numerical Features have encoded with :Scaler
#
# INFO  [07-20 22:49:41] start tuning  with Surrogate Model:GP...
#
# took CPU Time: 440.0s,clock time: 312.0, candidates checked:99 ,best CV score: 0.69367129 ± 0.0129
#
# INFO  [07-20 22:54:53] start tuning  with Surrogate Model:RF...
#
# took CPU Time: 132.0s,clock time: 210.0, candidates checked:200 ,best CV score: 0.69488867 ± 0.0145
#
#
# ######## Congratulations! Here is the Best Parameters: #######
# Best Score is: 0.6948886686050443
# with Surrogate Model RF
# {'model': LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         feature_fraction=0.9154832946905528, importance_type='split',
#         is_unbalance=False, learning_rate=0.13318419513471152, max_bin=204,
#         max_depth=-1, min_child_samples=20, min_child_weight=0.001,
#         min_split_gain=0.0, n_estimators=426, n_jobs=-1, nthread=-1,
#         num_leaves=31, objective='binary', random_state=None,
#         reg_alpha=0.6948898501513902, reg_lambda=348.5821679705963, seed=0,
#         silent=True, subsample=1.0, subsample_for_bin=200000,
#         subsample_freq=0),
#  'model__boosting_type': 'gbdt',
#  'model__feature_fraction': 0.9154832946905528,
#  'model__is_unbalance': False,
#  'model__learning_rate': 0.13318419513471152,
#  'model__max_bin': 204,
#  'model__n_estimators': 426,
#  'model__reg_alpha': 0.6948898501513902,
#  'model__reg_lambda': 348.5821679705963}
# End   [optimise_step]. Time elapsed: 521.37 sec.
#
# >>>>>> npoints: 10
#
# Start [optimise_step]:
# INFO  [07-20 22:58:22] Start turning Hyperparameters ....
#
# >>> Categorical Features have encoded with :{'strategy': 'label_encoding'}
#
# >>> Numerical Features have encoded with :Scaler
#
# INFO  [07-20 22:58:22] start tuning  with Surrogate Model:GP...
#
# took CPU Time: 379.0s,clock time: 263.0, candidates checked:100 ,best CV score: 0.6955799 ± 0.0114
#
# INFO  [07-20 23:02:46] start tuning  with Surrogate Model:RF...
#
# took CPU Time: 121.0s,clock time: 186.0, candidates checked:200 ,best CV score: 0.69098016 ± 0.0107
#
#
# ######## Congratulations! Here is the Best Parameters: #######
# Best Score is: 0.6955799046049255
# with Surrogate Model GP
# {'model': LGBMClassifier(boosting_type='dart', class_weight=None, colsample_bytree=1.0,
#         feature_fraction=0.9607740051068241, importance_type='split',
#         is_unbalance=False, learning_rate=0.8788203853954335, max_bin=3171,
#         max_depth=-1, min_child_samples=20, min_child_weight=0.001,
#         min_split_gain=0.0, n_estimators=500, n_jobs=-1, nthread=-1,
#         num_leaves=31, objective='binary', random_state=None,
#         reg_alpha=1e-09, reg_lambda=1000.0, seed=0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0),
#  'model__boosting_type': 'dart',
#  'model__feature_fraction': 0.9607740051068241,
#  'model__is_unbalance': False,
#  'model__learning_rate': 0.8788203853954335,
#  'model__max_bin': 3171,
#  'model__n_estimators': 500,
#  'model__reg_alpha': 1e-09,
#  'model__reg_lambda': 1000.0}
# End   [optimise_step]. Time elapsed: 449.98 sec.
# Dump successful! File Name: jm1_parallel_np_5f_100_eips.json

# %%
from util import dump_result,load_result
import pandas as pd
np_results =load_result("jm1_parallel_np_5f_40_eips_20190720211433.json")
score = []
for k in np_results.keys():
    bests = pd.DataFrame()
    for key in np_results[k].keys():
        if np_results[k][key]['best_score'] == max(d['best_score'] for d in np_results[k].values()):
            bests = bests.append({'best_score': np_results[k][key]['best_score'],
                                  'best_SM': key,
                                  'time': np_results[k][key]['CPU_Time']}, ignore_index=True)
            bests.sort_values(by=['time'])
            best_base_estimator = bests['best_SM'][0]
    #print(np_results[k][best_base_estimator]['best_score'])
    score.append(np_results[k][best_base_estimator]['best_score'])

re =load_result("jm1_parallel_np_5f_50_eips_20190720201017.json")
score_2 = []
for k in re.keys():
    bests = pd.DataFrame()
    for key in re[k].keys():
        if re[k][key]['best_score'] == max(d['best_score'] for d in re[k].values()):
            bests = bests.append({'best_score': re[k][key]['best_score'],
                                  'best_SM': key,
                                  'time': re[k][key]['CPU_Time']}, ignore_index=True)
            bests.sort_values(by=['time'])
            best_base_estimator = bests['best_SM'][0]
    score_2.append(re[k][best_base_estimator]['best_score'])

    
re_20 =load_result("jm1_parallel_np_5f_20_eips_20190720202853.json")
score_3 = []
for k in re_20.keys():
    bests = pd.DataFrame()
    for key in re_20[k].keys():
        if re_20[k][key]['best_score'] == max(d['best_score'] for d in re_20[k].values()):
            bests = bests.append({'best_score': re_20[k][key]['best_score'],
                                  'best_SM': key,
                                  'time': re_20[k][key]['CPU_Time']}, ignore_index=True)
            bests.sort_values(by=['time'])
            best_base_estimator = bests['best_SM'][0]
    score_3.append(re_20[k][best_base_estimator]['best_score'])
    

re_100 =load_result("jm1_parallel_np_5f_100_eips.json")
score_4 = []
for k in re_100.keys():
    bests = pd.DataFrame()
    for key in re_100[k].keys():
        if re_100[k][key]['best_score'] == max(d['best_score'] for d in re_100[k].values()):
            bests = bests.append({'best_score': re_100[k][key]['best_score'],
                                  'best_SM': key,
                                  'time': re_100[k][key]['CPU_Time']}, ignore_index=True)
            bests.sort_values(by=['time'])
            best_base_estimator = bests['best_SM'][0]
    score_4.append(re_100[k][best_base_estimator]['best_score'])
    
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(20,8))
ax = fig.add_subplot(111)
x_1 = score
x_2 = score_2
x_3 = score_3
x_4 = score_4
y = range(1,11)
p = ax.plot(y,x_1,label="iter40",marker =".",markersize = 15)
p_2 = ax.plot(y,x_2,label="iter50" ,marker ="." ,markersize = 15)
p_3 = ax.plot(y,x_3,label="iter20" ,marker =".",markersize = 15)
p_4 = ax.plot(y,x_4,label="iter100" ,marker =".",markersize = 15)
ax.set_xlabel('n-points')
plt.grid()
plt.legend()
fig.show()
fig.savefig(DIRS['output']+'auc_compare_npoints.png', dpi=fig.dpi)
# Out:
# /anaconda3/lib/python3.7/site-packages/matplotlib/figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %%
def get_runtime(results):
    time_all = {}
    for k in results.keys():
        temp=[]
        #print(k)
        for b in results[k].keys():
            temp.append(results[k][b]["CPU_Time"])
            time_all[k]=sum(temp)
    return pd.DataFrame(list(time_all.items()), columns=['npoints', 'cpu_time'])
t_20 = get_runtime(re_20)
t_40 = get_runtime(np_results)
t_50 = get_runtime(re) 
t_100 = get_runtime(re_100)

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(211)
width = 0.2
x_1 = score
x_2 = score_2
x_3 = score_3
x_4 = score_4
y = range(1,11)
y = np.arange(len(y)) 
ax.bar(y,x_3,width,alpha = 0.8,label="iterations20",color="#a3c9c7")#,color='grey', edgecolor='black'
ax.bar(y+width,x_1,width,alpha = 0.8,label="iterations40",color="#ff5f2e")
ax.bar(y+2*width,x_2,width,alpha =0.8,label="iterations50",color="#fcbe32")
ax.bar(y+3*width,x_4,width,alpha = 0.8,label="iterations100",color="#004e66")
ax.set_xticks(y +width/2)
ax.set_ylim((0.688, 0.698))
ax.set_ylabel('AUC',fontsize='15')
ax.set_xticks([])
ax.legend()
ax.grid()


ax2 = fig.add_subplot(212)  # 这个很重要噢
ax2.plot(t_20['npoints'],t_20['cpu_time'], label="iterations20",marker='*',ms=10,lw=3,color="#a3c9c7")
ax2.plot(t_40['npoints'],t_40['cpu_time'],label="iterations40",marker ="*",ms=10,lw=3,color="#ff5f2e")
ax2.plot(t_50['npoints'],t_50['cpu_time'],label="iterations50",marker ="*",ms=10,lw=3,color="#fcbe32")
ax2.plot(t_100['npoints'],t_100['cpu_time'],label="iterations100",marker ="*",ms=10,lw=3,color="#004e66")
ax2.set_ylabel('CPU time/s',fontsize='15')
ax2.legend()
ax2.set_xlabel('n-points')
ax2.grid()
fig.show()
#fig.savefig(DIRS['output']+'auc_compare_npoints.png', dpi=fig.dpi)
